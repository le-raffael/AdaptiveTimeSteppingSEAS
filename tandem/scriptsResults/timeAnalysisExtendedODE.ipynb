# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cbook as cbook
import csv
import pylab
from scipy.interpolate import interp1d


np.set_printoptions(threshold=sys.maxsize)

begin_surroundings = 198
end_surroundings = 199

begin_earthquake = 6259313254
end_earthquake =   6259316754

# %%
time_list_ext_rtol5 = []
dt_array_ext_rtol5 = []
V_array_ext_rtol5 = []
f_array_ext_rtol5 = []
rhs_count_array_ext_rtol5 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/timeAnalysis_extODE_rtol-5.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_rtol5.append(time)
            dt_array_ext_rtol5.append(dt)

            V_array_ext_rtol5.append(row['Vmax'])
            f_array_ext_rtol5.append(row['fmax'])
            rhs_count_array_ext_rtol5.append(row['count_rhs'])

time_array_ext_rtol5 = np.asarray(time_list_ext_rtol5, dtype=np.float64)
dt_array_ext_rtol5 = np.asarray(dt_array_ext_rtol5, dtype=np.float64)
V_array_ext_rtol5 = np.asarray(V_array_ext_rtol5, dtype=np.float64)
f_array_ext_rtol5 = np.asarray(f_array_ext_rtol5, dtype=np.float64)
rhs_count_array_ext_rtol5 = np.asarray(rhs_count_array_ext_rtol5, dtype=np.float64)

time_years_ext_rtol5 = time_array_ext_rtol5 / (365.2425*24*3600)

# %%
time_list_ext_rtol6 = []
dt_array_ext_rtol6 = []
V_array_ext_rtol6 = []
f_array_ext_rtol6 = []
rhs_count_array_ext_rtol6 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/timeAnalysis_extODE_rtol-6.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_rtol6.append(time)
            dt_array_ext_rtol6.append(dt)

            V_array_ext_rtol6.append(row['Vmax'])
            f_array_ext_rtol6.append(row['fmax'])
            rhs_count_array_ext_rtol6.append(row['count_rhs'])

time_array_ext_rtol6 = np.asarray(time_list_ext_rtol6, dtype=np.float64)
dt_array_ext_rtol6 = np.asarray(dt_array_ext_rtol6, dtype=np.float64)
V_array_ext_rtol6 = np.asarray(V_array_ext_rtol6, dtype=np.float64)
f_array_ext_rtol6 = np.asarray(f_array_ext_rtol6, dtype=np.float64)
rhs_count_array_ext_rtol6 = np.asarray(rhs_count_array_ext_rtol6, dtype=np.float64)

time_years_ext_rtol6 = time_array_ext_rtol6 / (365.2425*24*3600)

# %%
time_list_ext_rtol7 = []
dt_array_ext_rtol7 = []
V_array_ext_rtol7 = []
f_array_ext_rtol7 = []
rhs_count_array_ext_rtol7 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/timeAnalysis_extODE_rtol-7.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_rtol7.append(time)
            dt_array_ext_rtol7.append(dt)

            V_array_ext_rtol7.append(row['Vmax'])
            f_array_ext_rtol7.append(row['fmax'])
            rhs_count_array_ext_rtol7.append(row['count_rhs'])

time_array_ext_rtol7 = np.asarray(time_list_ext_rtol7, dtype=np.float64)
dt_array_ext_rtol7 = np.asarray(dt_array_ext_rtol7, dtype=np.float64)
V_array_ext_rtol7 = np.asarray(V_array_ext_rtol7, dtype=np.float64)
f_array_ext_rtol7 = np.asarray(f_array_ext_rtol7, dtype=np.float64)
rhs_count_array_ext_rtol7 = np.asarray(rhs_count_array_ext_rtol7, dtype=np.float64)

time_years_ext_rtol7 = time_array_ext_rtol7 / (365.2425*24*3600)

# %%
time_list_ext_rtol8 = []
dt_array_ext_rtol8 = []
V_array_ext_rtol8 = []
f_array_ext_rtol8 = []
rhs_count_array_ext_rtol8 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/timeAnalysis_extODE_rtol-8.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_rtol8.append(time)
            dt_array_ext_rtol8.append(dt)

            V_array_ext_rtol8.append(row['Vmax'])
            f_array_ext_rtol8.append(row['fmax'])
            rhs_count_array_ext_rtol8.append(row['count_rhs'])

time_array_ext_rtol8 = np.asarray(time_list_ext_rtol8, dtype=np.float64)
dt_array_ext_rtol8 = np.asarray(dt_array_ext_rtol8, dtype=np.float64)
V_array_ext_rtol8 = np.asarray(V_array_ext_rtol8, dtype=np.float64)
f_array_ext_rtol8 = np.asarray(f_array_ext_rtol8, dtype=np.float64)
rhs_count_array_ext_rtol8 = np.asarray(rhs_count_array_ext_rtol8, dtype=np.float64)

time_years_ext_rtol8 = time_array_ext_rtol8 / (365.2425*24*3600)

# %%
time_list_RKDP5 = []
dt_array_RKDP5 = []
V_array_RKDP5 = []
rhs_count_array_RKDP5 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/timeAnalysis_RKDP5_size5_1000years.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_RKDP5.append(time)
            dt_array_RKDP5.append(dt)

            V_array_RKDP5.append(row['Vmax'])
            rhs_count_array_RKDP5.append(row['count_rhs'])

time_array_RKDP5 = np.asarray(time_list_RKDP5, dtype=np.float64)
dt_array_RKDP5 = np.asarray(dt_array_RKDP5, dtype=np.float64)
V_array_RKDP5 = np.asarray(V_array_RKDP5, dtype=np.float64)
rhs_count_array_RKDP5 = np.asarray(rhs_count_array_RKDP5, dtype=np.float64)

time_years_RKDP5 = time_array_RKDP5 / (365.2425*24*3600)

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

plt.plot(time_years_RKDP5, V_array_RKDP5,'-g', label = "1st order ODE")
plt.plot(time_years_ext_rtol7, V_array_ext_rtol7,'b', linestyle='--', dashes=(2, 5), label = "2nd order ODE")

plt.xlabel("time [y]")
plt.ylabel("Vmax [m/s]")

plt.yscale('log')

plt.legend()

plt.savefig('../results/TANDEMtimeEvolutionVExtendedODE1stvs2ndOrder.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

plt.plot(time_years_ext_rtol5, f_array_ext_rtol5,'-r', label = "rtol=1e-5 ")
plt.plot(time_years_ext_rtol6, f_array_ext_rtol6,'-b', label = "rtol=1e-6 ")
plt.plot(time_years_ext_rtol7, f_array_ext_rtol7,'-g', label = "rtol=1e-7 ")
plt.plot(time_years_ext_rtol8, f_array_ext_rtol8,'-y', label = "rtol=1e-8 ")

plt.xlabel("time [y]")
plt.ylabel("fmax")

plt.yscale('log')

plt.ylim(1e-8,1e-2)

plt.legend()

plt.savefig('../results/TANDEMtimeEvolutionFExtendedODEDifferentTolerances.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

n=50
f_array_ext_left  = np.copy(f_array_ext_rtol5)
f_array_ext_right = np.copy(f_array_ext_rtol5)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_rtol5_change = f_array_ext_left - f_array_ext_right
f_array_ext_rtol5_change = np.abs(f_array_ext_rtol5_change)
f_array_ext_rtol5_change /= 2*n

f_array_ext_left  = np.copy(f_array_ext_rtol6)
f_array_ext_right = np.copy(f_array_ext_rtol6)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_rtol6_change = f_array_ext_left - f_array_ext_right
f_array_ext_rtol6_change = np.abs(f_array_ext_rtol6_change)
f_array_ext_rtol6_change /= 2*n

f_array_ext_left  = np.copy(f_array_ext_rtol7)
f_array_ext_right = np.copy(f_array_ext_rtol7)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_rtol7_change = f_array_ext_left - f_array_ext_right
f_array_ext_rtol7_change = np.abs(f_array_ext_rtol7_change)
f_array_ext_rtol7_change /= 2*n

f_array_ext_left  = np.copy(f_array_ext_rtol8)
f_array_ext_right = np.copy(f_array_ext_rtol8)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_rtol8_change = f_array_ext_left - f_array_ext_right
f_array_ext_rtol8_change = np.abs(f_array_ext_rtol8_change)
f_array_ext_rtol8_change /= 2*n


plt.plot(time_years_ext_rtol5[n:-n], f_array_ext_rtol5_change[n:-n],'-r', label = "rtol=1e-5 ")
plt.plot(time_years_ext_rtol6[n:-n], f_array_ext_rtol6_change[n:-n],'-b', label = "rtol=1e-6 ")
plt.plot(time_years_ext_rtol7[n:-n], f_array_ext_rtol7_change[n:-n],'-g', label = "rtol=1e-7 ")
plt.plot(time_years_ext_rtol8[n:-n], f_array_ext_rtol8_change[n:-n],'-y', label = "rtol=1e-8 ")

plt.xlabel("time [y]")
plt.ylabel("change in fmax")

plt.yscale('log')

#plt.ylim(1e-8,1e-2)

plt.legend()

plt.savefig('../results/TANDEMtimeEvolutionFLTEExtendedODEDifferentTolerances.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
time_list_ext_size5 = []
dt_array_ext_size5 = []
V_array_ext_size5 = []
f_array_ext_size5 = []
rhs_count_array_ext_size5 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/timeAnalysis_extODE_size5.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_size5.append(time)
            dt_array_ext_size5.append(dt)

            V_array_ext_size5.append(row['Vmax'])
            f_array_ext_size5.append(row['fmax'])
            rhs_count_array_ext_size5.append(row['count_rhs'])

time_array_ext_size5 = np.asarray(time_list_ext_size5, dtype=np.float64)
dt_array_ext_size5 = np.asarray(dt_array_ext_size5, dtype=np.float64)
V_array_ext_size5 = np.asarray(V_array_ext_size5, dtype=np.float64)
f_array_ext_size5 = np.asarray(f_array_ext_size5, dtype=np.float64)
rhs_count_array_ext_size5 = np.asarray(rhs_count_array_ext_size5, dtype=np.float64)

time_years_ext_size5 = time_array_ext_size5 / (365.2425*24*3600)

# %%
time_list_ext_size10 = []
dt_array_ext_size10 = []
V_array_ext_size10 = []
f_array_ext_size10 = []
rhs_count_array_ext_size10 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/timeAnalysis_extODE_size10.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_size10.append(time)
            dt_array_ext_size10.append(dt)

            V_array_ext_size10.append(row['Vmax'])
            f_array_ext_size10.append(row['fmax'])
            rhs_count_array_ext_size10.append(row['count_rhs'])

time_array_ext_size10 = np.asarray(time_list_ext_size10, dtype=np.float64)
dt_array_ext_size10 = np.asarray(dt_array_ext_size10, dtype=np.float64)
V_array_ext_size10 = np.asarray(V_array_ext_size10, dtype=np.float64)
f_array_ext_size10 = np.asarray(f_array_ext_size10, dtype=np.float64)
rhs_count_array_ext_size10 = np.asarray(rhs_count_array_ext_size10, dtype=np.float64)

time_years_ext_size10 = time_array_ext_size10 / (365.2425*24*3600)

# %%
time_list_ext_size68 = []
dt_array_ext_size68 = []
V_array_ext_size68 = []
f_array_ext_size68 = []
rhs_count_array_ext_size68 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/timeAnalysis_extODE_size68.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_size68.append(time)
            dt_array_ext_size68.append(dt)

            V_array_ext_size68.append(row['Vmax'])
            f_array_ext_size68.append(row['fmax'])
            rhs_count_array_ext_size68.append(row['count_rhs'])

time_array_ext_size68 = np.asarray(time_list_ext_size68, dtype=np.float64)
dt_array_ext_size68 = np.asarray(dt_array_ext_size68, dtype=np.float64)
V_array_ext_size68 = np.asarray(V_array_ext_size68, dtype=np.float64)
f_array_ext_size68 = np.asarray(f_array_ext_size68, dtype=np.float64)
rhs_count_array_ext_size68 = np.asarray(rhs_count_array_ext_size68, dtype=np.float64)

time_years_ext_size68 = time_array_ext_size68 / (365.2425*24*3600)

# %%
time_list_ext_size200 = []
dt_array_ext_size200 = []
V_array_ext_size200 = []
f_array_ext_size200 = []
rhs_count_array_ext_size200 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../build/timeAnalysis.csv', newline='') as csvfile:
#with open('../results/timeAnalysis_extODE_size200.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_size200.append(time)
            dt_array_ext_size200.append(dt)

            V_array_ext_size200.append(row['Vmax'])
            f_array_ext_size200.append(row['fmax'])
            rhs_count_array_ext_size200.append(row['count_rhs'])

time_array_ext_size200 = np.asarray(time_list_ext_size200, dtype=np.float64)
dt_array_ext_size200 = np.asarray(dt_array_ext_size200, dtype=np.float64)
V_array_ext_size200 = np.asarray(V_array_ext_size200, dtype=np.float64)
f_array_ext_size200 = np.asarray(f_array_ext_size200, dtype=np.float64)
rhs_count_array_ext_size200 = np.asarray(rhs_count_array_ext_size200, dtype=np.float64)

time_years_ext_size200 = time_array_ext_size200 / (365.2425*24*3600)

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

print

plt.plot(time_years_ext_size5, V_array_ext_size5,'-r', label = "n=5")
plt.plot(time_years_ext_size10, V_array_ext_size10,'-b', label = "n=10")
plt.plot(time_years_ext_size68, V_array_ext_size68,'-g', label = "n=68")
plt.plot(time_years_ext_size200, V_array_ext_size200,'-y', label = "n=200")

plt.xlabel("time [y]")
plt.ylabel("Vmax [m/s]")

plt.yscale('log')

plt.legend()

plt.savefig('../results/TANDEMtimeEvolutionVExtendedODEDifferentSizes.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

plt.plot(time_years_ext_size5, f_array_ext_size5,'-r', label = "n=5 ")
plt.plot(time_years_ext_size10, f_array_ext_size10,'-b', label = "n=10 ")
plt.plot(time_years_ext_size68, f_array_ext_size68,'-g', label = "n=68 ")
plt.plot(time_years_ext_size200, f_array_ext_size200,'-y', label = "n=200 ")

plt.xlabel("time [y]")
plt.ylabel("fmax")

plt.yscale('log')

plt.ylim(1e-7,1e-4)

plt.legend()

plt.savefig('../results/TANDEMtimeEvolutionFExtendedODEDifferentSizes.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

n=100
f_array_ext_left  = np.copy(f_array_ext_size5)
f_array_ext_right = np.copy(f_array_ext_size5)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_size5_change = f_array_ext_left - f_array_ext_right
f_array_ext_size5_change = np.abs(f_array_ext_size5_change)
f_array_ext_size5_change /= 2*n

f_array_ext_left  = np.copy(f_array_ext_size10)
f_array_ext_right = np.copy(f_array_ext_size10)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_size10_change = f_array_ext_left - f_array_ext_right
f_array_ext_size10_change = np.abs(f_array_ext_size10_change)
f_array_ext_size10_change /= 2*n

f_array_ext_left  = np.copy(f_array_ext_size68)
f_array_ext_right = np.copy(f_array_ext_size68)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_size68_change = f_array_ext_left - f_array_ext_right
f_array_ext_size68_change = np.abs(f_array_ext_size68_change)
f_array_ext_size68_change /= 2*n

f_array_ext_left  = np.copy(f_array_ext_size200)
f_array_ext_right = np.copy(f_array_ext_size200)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_size200_change = f_array_ext_left - f_array_ext_right
f_array_ext_size200_change = np.abs(f_array_ext_size200_change)
f_array_ext_size200_change /= 2*n


plt.plot(time_years_ext_size5[n:-n], f_array_ext_size5_change[n:-n],'-r', label = "n=5 ")
plt.plot(time_years_ext_size10[n:-n], f_array_ext_size10_change[n:-n],'-b', label = "n=10 ")
plt.plot(time_years_ext_size68[n:-n], f_array_ext_size68_change[n:-n],'-g', label = "n=68 ")
plt.plot(time_years_ext_size200[n:-n], f_array_ext_size200_change[n:-n],'-y', label = "n=200 ")

plt.xlabel("time [y]")
plt.ylabel("change of fmax")

plt.yscale('log')

#plt.ylim(1e-8,1e-2)

plt.legend()

plt.savefig('../results/TANDEMtimeEvolutionFLTEExtendedODEDifferentSizes.png', format='png',dpi=300, bbox_inches='tight')

plt.show()
