# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cbook as cbook
import csv
import pylab
from scipy.interpolate import interp1d


np.set_printoptions(threshold=sys.maxsize)



begin_surroundings = 196
end_surroundings = 206

#begin_earthquake = 6259313254
begin_earthquake = 6259295000
end_earthquake =   6259320000

# %%
time_list_tolem2 = []
dt_array_tolem2 = []
V_array_tolem2 = []
S_array_tolem2 = []
rhs_count_array_tolem2 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-02.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_tolem2.append(time)
            dt_array_tolem2.append(dt)

            V_array_tolem2.append(row['Vmax'])
            S_array_tolem2.append(row['minS'])
            rhs_count_array_tolem2.append(row['count_rhs'])

time_array_tolem2 = np.asarray(time_list_tolem2, dtype=np.float64)
dt_array_tolem2 = np.asarray(dt_array_tolem2, dtype=np.float64)
V_array_tolem2 = np.asarray(V_array_tolem2, dtype=np.float64)
S_array_tolem2 = np.asarray(S_array_tolem2, dtype=np.float64)
rhs_count_array_tolem2 = np.asarray(rhs_count_array_tolem2, dtype=np.float64)

time_years_tolem2 = time_array_tolem2 / (365.2425*24*3600)

# %%
time_list_tolem3 = []
dt_array_tolem3 = []
V_array_tolem3 = []
S_array_tolem3 = []
rhs_count_array_tolem3 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-03.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_tolem3.append(time)
            dt_array_tolem3.append(dt)

            V_array_tolem3.append(row['Vmax'])
            S_array_tolem3.append(row['minS'])
            rhs_count_array_tolem3.append(row['count_rhs'])

time_array_tolem3 = np.asarray(time_list_tolem3, dtype=np.float64)
dt_array_tolem3 = np.asarray(dt_array_tolem3, dtype=np.float64)
V_array_tolem3 = np.asarray(V_array_tolem3, dtype=np.float64)
S_array_tolem3 = np.asarray(S_array_tolem3, dtype=np.float64)
rhs_count_array_tolem3 = np.asarray(rhs_count_array_tolem3, dtype=np.float64)

time_years_tolem3 = time_array_tolem3 / (365.2425*24*3600)

# %%
time_list_tolem4 = []
dt_array_tolem4 = []
V_array_tolem4 = []
Smin_array_tolem4 = []
Smax_array_tolem4 = []
rhs_count_array_tolem4 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-04.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_tolem4.append(time)
            dt_array_tolem4.append(dt)

            V_array_tolem4.append(row['Vmax'])
            Smin_array_tolem4.append(row['minS'])
            Smax_array_tolem4.append(row['minS'])
            rhs_count_array_tolem4.append(row['count_rhs'])

time_array_tolem4 = np.asarray(time_list_tolem4, dtype=np.float64)
dt_array_tolem4 = np.asarray(dt_array_tolem4, dtype=np.float64)
V_array_tolem4 = np.asarray(V_array_tolem4, dtype=np.float64)
Smin_array_tolem4 = np.asarray(Smin_array_tolem4, dtype=np.float64)
Smax_array_tolem4 = np.asarray(Smax_array_tolem4, dtype=np.float64)
rhs_count_array_tolem4 = np.asarray(rhs_count_array_tolem4, dtype=np.float64)

time_years_tolem4 = time_array_tolem4 / (365.2425*24*3600)

# %%
time_list_tolem5 = []
dt_array_tolem5 = []
V_array_tolem5 = []
Smin_array_tolem5 = []
Smax_array_tolem5 = []
rhs_count_array_tolem5 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_tolem5.append(time)
            dt_array_tolem5.append(dt)

            V_array_tolem5.append(row['Vmax'])
            Smin_array_tolem5.append(row['minS'])
            Smax_array_tolem5.append(row['maxS'])
            rhs_count_array_tolem5.append(row['count_rhs'])

time_array_tolem5 = np.asarray(time_list_tolem5, dtype=np.float64)
dt_array_tolem5 = np.asarray(dt_array_tolem5, dtype=np.float64)
V_array_tolem5 = np.asarray(V_array_tolem5, dtype=np.float64)
Smin_array_tolem5 = np.asarray(Smin_array_tolem5, dtype=np.float64)
Smax_array_tolem5 = np.asarray(Smax_array_tolem5, dtype=np.float64)
rhs_count_array_tolem5 = np.asarray(rhs_count_array_tolem5, dtype=np.float64)

time_years_tolem5 = time_array_tolem5 / (365.2425*24*3600)

# %%
time_list_tolem6 = []
dt_array_tolem6 = []
V_array_tolem6 = []
Smin_array_tolem6 = []
Smax_array_tolem6 = []
rhs_count_array_tolem6 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-06.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_tolem6.append(time)
            dt_array_tolem6.append(dt)

            V_array_tolem6.append(row['Vmax'])
            Smin_array_tolem6.append(row['minS'])
            Smax_array_tolem6.append(row['maxS'])
            rhs_count_array_tolem6.append(row['count_rhs'])

time_array_tolem6 = np.asarray(time_list_tolem6, dtype=np.float64)
dt_array_tolem6 = np.asarray(dt_array_tolem6, dtype=np.float64)
V_array_tolem6 = np.asarray(V_array_tolem6, dtype=np.float64)
Smax_array_tolem6 = np.asarray(Smax_array_tolem6, dtype=np.float64)
Smin_array_tolem6 = np.asarray(Smin_array_tolem6, dtype=np.float64)
rhs_count_array_tolem6 = np.asarray(rhs_count_array_tolem6, dtype=np.float64)

time_years_tolem6 = time_array_tolem6 / (365.2425*24*3600)

# %%
time_list_tolem7 = []
dt_array_tolem7 = []
V_array_tolem7 = []
Smin_array_tolem7 = []
Smax_array_tolem7 = []
rhs_count_array_tolem7 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-07.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_tolem7.append(time)
            dt_array_tolem7.append(dt)

            V_array_tolem7.append(row['Vmax'])
            Smin_array_tolem7.append(row['minS'])
            Smax_array_tolem7.append(row['maxS'])
            rhs_count_array_tolem7.append(row['count_rhs'])

time_array_tolem7 = np.asarray(time_list_tolem7, dtype=np.float64)
dt_array_tolem7 = np.asarray(dt_array_tolem7, dtype=np.float64)
V_array_tolem7 = np.asarray(V_array_tolem7, dtype=np.float64)
Smin_array_tolem7 = np.asarray(Smin_array_tolem7, dtype=np.float64)
Smax_array_tolem7 = np.asarray(Smax_array_tolem7, dtype=np.float64)
rhs_count_array_tolem7 = np.asarray(rhs_count_array_tolem7, dtype=np.float64)

time_years_tolem7 = time_array_tolem7 / (365.2425*24*3600)

# %%
time_list_tolem8 = []
dt_array_tolem8 = []
V_array_tolem8 = []
Smin_array_tolem8 = []
Smax_array_tolem8 = []
rhs_count_array_tolem8 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-08.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_tolem8.append(time)
            dt_array_tolem8.append(dt)

            V_array_tolem8.append(row['Vmax'])
            Smin_array_tolem8.append(row['minS'])
            Smax_array_tolem8.append(row['maxS'])
            rhs_count_array_tolem8.append(row['count_rhs'])

time_array_tolem8 = np.asarray(time_list_tolem8, dtype=np.float64)
dt_array_tolem8 = np.asarray(dt_array_tolem8, dtype=np.float64)
V_array_tolem8 = np.asarray(V_array_tolem8, dtype=np.float64)
Smax_array_tolem8 = np.asarray(Smax_array_tolem8, dtype=np.float64)
Smin_array_tolem8 = np.asarray(Smin_array_tolem8, dtype=np.float64)
rhs_count_array_tolem8 = np.asarray(rhs_count_array_tolem8, dtype=np.float64)

time_years_tolem8 = time_array_tolem8 / (365.2425*24*3600)

# %%
time_list_tolem9 = []
dt_array_tolem9 = []
V_array_tolem9 = []
Smin_array_tolem9 = []
Smax_array_tolem9 = []
rhs_count_array_tolem9 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-09.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_tolem9.append(time)
            dt_array_tolem9.append(dt)

            V_array_tolem9.append(row['Vmax'])
            Smin_array_tolem9.append(row['minS'])
            Smax_array_tolem9.append(row['maxS'])
            rhs_count_array_tolem9.append(row['count_rhs'])

time_array_tolem9 = np.asarray(time_list_tolem9, dtype=np.float64)
dt_array_tolem9 = np.asarray(dt_array_tolem9, dtype=np.float64)
V_array_tolem9 = np.asarray(V_array_tolem9, dtype=np.float64)
Smin_array_tolem9 = np.asarray(Smin_array_tolem9, dtype=np.float64)
Smax_array_tolem9 = np.asarray(Smax_array_tolem9, dtype=np.float64)
rhs_count_array_tolem9 = np.asarray(rhs_count_array_tolem9, dtype=np.float64)

time_years_tolem9 = time_array_tolem9 / (365.2425*24*3600)

# %%
time_list_tolem10 = []
dt_array_tolem10 = []
V_array_tolem10 = []
Smin_array_tolem10 = []
Smax_array_tolem10 = []
rhs_count_array_tolem10 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-10.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_tolem10.append(time)
            dt_array_tolem10.append(dt)

            V_array_tolem10.append(row['Vmax'])
            Smax_array_tolem10.append(row['minS'])
            Smin_array_tolem10.append(row['maxS'])
            rhs_count_array_tolem10.append(row['count_rhs'])

time_array_tolem10 = np.asarray(time_list_tolem10, dtype=np.float64)
dt_array_tolem10 = np.asarray(dt_array_tolem10, dtype=np.float64)
V_array_tolem10 = np.asarray(V_array_tolem10, dtype=np.float64)
Smin_array_tolem10 = np.asarray(Smin_array_tolem10, dtype=np.float64)
Smax_array_tolem10 = np.asarray(Smax_array_tolem10, dtype=np.float64)
rhs_count_array_tolem10 = np.asarray(rhs_count_array_tolem10, dtype=np.float64)

time_years_tolem10 = time_array_tolem10 / (365.2425*24*3600)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-b921ee0b6ea1> in <module>
#      10 second = 1
#      11
# ---> 12 with open('../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-10.csv', newline='') as csvfile:
#      13     reader = csv.DictReader(csvfile)
#      14     for row in reader:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-10.csv'

# %%
time_list_tolem11 = []
dt_array_tolem11 = []
V_array_tolem11 = []
Smin_array_tolem11 = []
Smax_array_tolem11 = []
rhs_count_array_tolem11 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-11.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_tolem11.append(time)
            dt_array_tolem11.append(dt)

            V_array_tolem11.append(row['Vmax'])
            Smin_array_tolem11.append(row['minS'])
            Smax_array_tolem11.append(row['maxS'])
            rhs_count_array_tolem11.append(row['count_rhs'])

time_array_tolem11 = np.asarray(time_list_tolem11, dtype=np.float64)
dt_array_tolem11 = np.asarray(dt_array_tolem11, dtype=np.float64)
V_array_tolem11 = np.asarray(V_array_tolem11, dtype=np.float64)
Smin_array_tolem11 = np.asarray(Smin_array_tolem11, dtype=np.float64)
Smax_array_tolem11 = np.asarray(Smax_array_tolem11, dtype=np.float64)
rhs_count_array_tolem11 = np.asarray(rhs_count_array_tolem11, dtype=np.float64)

time_years_tolem11 = time_array_tolem11 / (365.2425*24*3600)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-0c0a4304fdf7> in <module>
#      10 second = 1
#      11
# ---> 12 with open('../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-11.csv', newline='') as csvfile:
#      13     reader = csv.DictReader(csvfile)
#      14     for row in reader:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/TANDEM_size101__AS_compactode_5dp_Stol1e-11__EQ_compactode_5dp_Stol1e-11.csv'

# %%
#extract slip after the earthquake
time_after = 7500000000
time_diff = np.abs(time_array_tolem4 - time_after)
i = time_diff.argmin()
if (time_after < time_array_tolem4[i]):
    i = i-1
left = (time_array_tolem4[i+1] - time_after) / (time_array_tolem4[i+1] - time_array_tolem4[i])
right = (time_after - time_array_tolem4[i]) / (time_array_tolem4[i+1] - time_array_tolem4[i])
S_after_tolem4 = left * Smin_array_tolem4[i] + right * Smin_array_tolem4[i+1]


# get maximum slip rate
Vmax_tolem4 = np.amax(V_array_tolem4)

# %%
#extract slip after the earthquake
time_after = 7500000000
time_diff = np.abs(time_array_tolem5 - time_after)
i = time_diff.argmin()
if (time_after < time_array_tolem5[i]):
    i = i-1
left = (time_array_tolem5[i+1] - time_after) / (time_array_tolem5[i+1] - time_array_tolem5[i])
right = (time_after - time_array_tolem5[i]) / (time_array_tolem5[i+1] - time_array_tolem5[i])
S_after_tolem5 = left * Smin_array_tolem5[i] + right * Smin_array_tolem5[i+1]


# get maximum slip rate
Vmax_tolem5 = np.amax(V_array_tolem5)

# %%
#extract slip after the earthquake
time_after = 7500000000
time_diff = np.abs(time_array_tolem6 - time_after)
i = time_diff.argmin()
if (time_after < time_array_tolem6[i]):
    i = i-1

left = (time_array_tolem6[i+1] - time_after) / (time_array_tolem6[i+1] - time_array_tolem6[i])
right = (time_after - time_array_tolem6[i]) / (time_array_tolem6[i+1] - time_array_tolem6[i])
S_after_tolem6 = left * Smin_array_tolem6[i] + right * Smin_array_tolem6[i+1]


# get maximum slip rate
Vmax_tolem6 = np.amax(V_array_tolem6)

# %%
#extract slip after the earthquake
time_after = 7500000000
time_diff = np.abs(time_array_tolem7 - time_after)
i = time_diff.argmin()
if (time_after <time_array_tolem7[i]):
    i = i-1
left = (time_array_tolem7[i+1] - time_after) / (time_array_tolem7[i+1] - time_array_tolem7[i])
right = (time_after - time_array_tolem7[i]) / (time_array_tolem7[i+1] - time_array_tolem7[i])
S_after_tolem7 = left * Smin_array_tolem7[i] + right * Smin_array_tolem7[i+1]


# get maximum slip rate
Vmax_tolem7 = np.amax(V_array_tolem7)

# %%
#extract slip after the earthquake
time_after = 7500000000
time_diff = np.abs(time_array_tolem8 - time_after)
i = time_diff.argmin()
if (time_after < time_array_tolem8[i]):
    i = i-1
left = (time_array_tolem8[i+1] - time_after) / (time_array_tolem8[i+1] - time_array_tolem8[i])
right = (time_after - time_array_tolem8[i]) / (time_array_tolem8[i+1] - time_array_tolem8[i])
S_after_tolem8 = left * Smin_array_tolem8[i] + right * Smin_array_tolem8[i+1]


# get maximum slip rate
Vmax_tolem8 = np.amax(V_array_tolem8)

# %%
#extract slip after the earthquake
time_after = 7500000000
time_diff = np.abs(time_array_tolem9 - time_after)
i = time_diff.argmin()
if (time_after < time_array_tolem9[i]):
    i = i-1
left = (time_array_tolem9[i+1] - time_after) / (time_array_tolem9[i+1] - time_array_tolem9[i])
right = (time_after - time_array_tolem9[i]) / (time_array_tolem9[i+1] - time_array_tolem9[i])
S_after_tolem9 = left * Smin_array_tolem9[i] + right * Smin_array_tolem9[i+1]

# get maximum slip rate
Vmax_tolem9= np.amax(V_array_tolem9)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-93-f5c12a2c1b84> in <module>
#       5 if (time_after < time_array_tolem9[i]):
#       6     i = i-1
# ----> 7 left = (time_array_tolem9[i+1] - time_after) / (time_array_tolem9[i+1] - time_array_tolem9[i])
#       8 right = (time_after - time_array_tolem9[i]) / (time_array_tolem9[i+1] - time_array_tolem9[i])
#       9 S_after_tolem9 = left * Smin_array_tolem9[i] + right * Smin_array_tolem9[i+1]
#
# IndexError: index 24574 is out of bounds for axis 0 with size 24574

# %%
#extract slip after the earthquake
time_after = 7500000000
time_diff = np.abs(time_array_tolem10 - time_after)
i = time_diff.argmin()
if (time_after < time_array_tolem10[i]):
    i = i-1
left = (time_array_tolem10[i+1] - time_after) / (time_array_tolem10[i+1] - time_array_tolem10[i])
right = (time_after - time_array_tolem10[i]) / (time_array_tolem10[i+1] - time_array_tolem10[i])
S_after_tolem10 = left * Smin_array_tolem10[i] + right * Smin_array_tolem10[i+1]


# get maximum slip rate
Vmax_tolem10 = V_array_tolem10.amax()
# Out:
# 6900842337.685256

# %%
#extract slip after the earthquake
time_after = 7500000000
time_diff = np.abs(time_array_tolem11 - time_after)
i = time_diff.argmin()
if (time_after < time_array_tolem11[i]):
    i = i-1
left = (time_array_tolem11[i+1] - time_after) / (time_array_tolem11[i+1] - time_array_tolem11[i])
right = (time_after - time_array_tolem11[i]) / (time_array_tolem11[i+1] - time_array_tolem11[i])
S_after_tolem11 = left * Smin_array_tolem11[i] + right * Smin_array_tolem11[i+1]


# get maximum slip rate
Vmax_tolem11 = V_array_tolem11.amax()
# Out:
# 6900842337.685256

# %%
tolerances = np.asarray([1e-4, 1e-5, 1e-6, 1e-7, 1e-8]) #, 1e-9, 1e-10, 1e-11])
S_after    = np.asarray([S_after_tolem4, S_after_tolem5, S_after_tolem6, S_after_tolem7, S_after_tolem8])#, S_after_tolem9, S_after_tolem10, S_after_tolem11])
Vmax       = np.asarray([Vmax_tolem4, Vmax_tolem5, Vmax_tolem6, Vmax_tolem7, Vmax_tolem8])#, Vmax_tolem9, Vmax_tolem10, Vmax_tolem11])

S_after = np.abs(S_after - S_after_tolem8)
Vmax    = np.abs(Vmax - Vmax_tolem8)

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

plt.plot(tolerances[:-1], S_after[:-1],'k-', marker=".",markersize=10)

plt.xlabel(r"tolerance in $S$")
plt.ylabel(r"Difference in $S$ [m]")

plt.yscale('log')
plt.xscale('log')

plt.savefig('../results/TANDEMcompactODEDifferentTolerancesSize101_EQ_Smin.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

plt.plot(tolerances[:-1], Vmax[:-1],'k-', marker=".",markersize=10)

plt.xlabel(r"tolerance in $S$")
plt.ylabel(r"Difference in $V_{max}$ [m/s]")

plt.yscale('log')
plt.xscale('log')

plt.savefig('../results/TANDEMcompactODEDifferentTolerancesSize101_EQ_Vmax.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
sigma = 1e-7
C = 1
e_S = 4e-12
e_psi = 2e-14
e_V = 2e-24

# %%
def dgdpsi():

    b = 0.015
    V0 = 1e-6
    L = 0.008
    f = 0.6
    psi_max = 0.7
    
    return V0 / L * (np.exp((f - psi_max) / b))

def dgdV():

    b = 0.015
    V0 = 1e-6
    L = 0.008
    f = 0.6
    psi_max = 0.7
    
    return b / L

# %%
# compact ODE
t_S = sigma * C * e_S + e_S + e_V
t_psi = sigma * C * e_psi + e_psi + dgdpsi() * e_psi + dgdV() * e_V
print("Newton tolerances: \n\t -tolerance in S: ", t_S, "\n\t -tolerance in psi:", t_psi)
# Out:
# Newton tolerances:
# 	 -tolerance in S:  4.000000400002e-12
# 	 -tolerance in psi: 2.00000051853345e-14
