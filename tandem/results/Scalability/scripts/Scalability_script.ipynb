# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cbook as cbook
import matplotlib.ticker as mticker
import csv
import pylab
from scipy.interpolate import interp1d


np.set_printoptions(threshold=sys.maxsize)

# %%
time_list_compactODEsize52 = []
dt_array_compactODEsize52 = []
V_array_compactODEsize52 = []
F_array_compactODEsize52 = []
rhs_count_array_compactODEsize52 = []
ksp_count_array_compactODEsize52 = []
max_S_compactODEsize52 = []
min_S_compactODEsize52 = []
max_PSI_compactODEsize52 = []
min_PSI_compactODEsize52 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size52__AS_compactode_5dp_Satol1e-08__EQ_compactode_5dp_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_compactODEsize52.append(time)
            dt_array_compactODEsize52.append(dt)

            V_array_compactODEsize52.append(row['Vmax'])
            F_array_compactODEsize52.append(row['fmax'])
            rhs_count_array_compactODEsize52.append(row['count_rhs'])
            ksp_count_array_compactODEsize52.append(row['KSP_iteration'])
            max_S_compactODEsize52.append(row['maxS'])
            min_S_compactODEsize52.append(row['minS'])
            max_PSI_compactODEsize52.append(row['maxPSI'])
            min_PSI_compactODEsize52.append(row['minPSI'])
            
            
            if (row['t_init']):
                initialization_time_compactODEsize52 = row['t_init']
            if (row['t_solve']):
                solve_time_compactODEsize52 = row['t_solve']
            if (row['t_total']):
                total_time_compactODEsize52 = row['t_total']

time_array_compactODEsize52 = np.asarray(time_list_compactODEsize52, dtype=np.float64)
dt_array_compactODEsize52 = np.asarray(dt_array_compactODEsize52, dtype=np.float64)
V_array_compactODEsize52 = np.asarray(V_array_compactODEsize52, dtype=np.float64)
F_array_compactODEsize52 = np.asarray(F_array_compactODEsize52, dtype=np.float64)
rhs_count_array_compactODEsize52 = np.asarray(rhs_count_array_compactODEsize52, dtype=np.float64)
ksp_count_array_compactODEsize52 = np.asarray(ksp_count_array_compactODEsize52, dtype=np.float64)
max_S_compactODEsize52 = np.asarray(max_S_compactODEsize52, dtype=np.float64)
min_S_compactODEsize52 = np.asarray(min_S_compactODEsize52, dtype=np.float64)
max_PSI_compactODEsize52 = np.asarray(max_PSI_compactODEsize52, dtype=np.float64)
min_PSI_compactODEsize52 = np.asarray(min_PSI_compactODEsize52, dtype=np.float64)

time_years_compactODEsize52 = time_array_compactODEsize52 / (365.2425*24*3600)

# %%
time_list_compactODEsize101 = []
dt_array_compactODEsize101 = []
V_array_compactODEsize101 = []
F_array_compactODEsize101 = []
rhs_count_array_compactODEsize101 = []
ksp_count_array_compactODEsize101 = []
max_S_compactODEsize101 = []
min_S_compactODEsize101 = []
max_PSI_compactODEsize101 = []
min_PSI_compactODEsize101 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_compactode_5dp_Satol1e-08__EQ_compactode_5dp_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_compactODEsize101.append(time)
            dt_array_compactODEsize101.append(dt)

            V_array_compactODEsize101.append(row['Vmax'])
            F_array_compactODEsize101.append(row['fmax'])
            rhs_count_array_compactODEsize101.append(row['count_rhs'])
            ksp_count_array_compactODEsize101.append(row['KSP_iteration'])
            max_S_compactODEsize101.append(row['maxS'])
            min_S_compactODEsize101.append(row['minS'])
            max_PSI_compactODEsize101.append(row['maxPSI'])
            min_PSI_compactODEsize101.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_compactODEsize101 = row['t_init']
            if (row['t_solve']):
                solve_time_compactODEsize101 = row['t_solve']
            if (row['t_total']):
                total_time_compactODEsize101 = row['t_total']

time_array_compactODEsize101 = np.asarray(time_list_compactODEsize101, dtype=np.float64)
dt_array_compactODEsize101 = np.asarray(dt_array_compactODEsize101, dtype=np.float64)
V_array_compactODEsize101 = np.asarray(V_array_compactODEsize101, dtype=np.float64)
F_array_compactODEsize101 = np.asarray(F_array_compactODEsize101, dtype=np.float64)
rhs_count_array_compactODEsize101 = np.asarray(rhs_count_array_compactODEsize101, dtype=np.float64)
ksp_count_array_compactODEsize101 = np.asarray(ksp_count_array_compactODEsize101, dtype=np.float64)
max_S_compactODEsize101 = np.asarray(max_S_compactODEsize101, dtype=np.float64)
min_S_compactODEsize101 = np.asarray(min_S_compactODEsize101, dtype=np.float64)
max_PSI_compactODEsize101 = np.asarray(max_PSI_compactODEsize101, dtype=np.float64)
min_PSI_compactODEsize101 = np.asarray(min_PSI_compactODEsize101, dtype=np.float64)

time_years_compactODEsize101 = time_array_compactODEsize101 / (365.2425*24*3600)

# %%
time_list_compactODEsize200 = []
dt_array_compactODEsize200 = []
V_array_compactODEsize200 = []
F_array_compactODEsize200 = []
rhs_count_array_compactODEsize200 = []
ksp_count_array_compactODEsize200 = []
max_S_compactODEsize200 = []
min_S_compactODEsize200 = []
max_PSI_compactODEsize200 = []
min_PSI_compactODEsize200 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size200__AS_compactode_5dp_Satol1e-08__EQ_compactode_5dp_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_compactODEsize200.append(time)
            dt_array_compactODEsize200.append(dt)

            V_array_compactODEsize200.append(row['Vmax'])
            F_array_compactODEsize200.append(row['fmax'])
            rhs_count_array_compactODEsize200.append(row['count_rhs'])
            ksp_count_array_compactODEsize200.append(row['KSP_iteration'])
            max_S_compactODEsize200.append(row['maxS'])
            min_S_compactODEsize200.append(row['minS'])
            max_PSI_compactODEsize200.append(row['maxPSI'])
            min_PSI_compactODEsize200.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_compactODEsize200 = row['t_init']
            if (row['t_solve']):
                solve_time_compactODEsize200 = row['t_solve']
            if (row['t_total']):
                total_time_compactODEsize200 = row['t_total']

time_array_compactODEsize200 = np.asarray(time_list_compactODEsize200, dtype=np.float64)
dt_array_compactODEsize200 = np.asarray(dt_array_compactODEsize200, dtype=np.float64)
V_array_compactODEsize200 = np.asarray(V_array_compactODEsize200, dtype=np.float64)
F_array_compactODEsize200 = np.asarray(F_array_compactODEsize200, dtype=np.float64)
rhs_count_array_compactODEsize200 = np.asarray(rhs_count_array_compactODEsize200, dtype=np.float64)
ksp_count_array_compactODEsize200 = np.asarray(ksp_count_array_compactODEsize200, dtype=np.float64)
max_S_compactODEsize200 = np.asarray(max_S_compactODEsize200, dtype=np.float64)
min_S_compactODEsize200 = np.asarray(min_S_compactODEsize200, dtype=np.float64)
max_PSI_compactODEsize200 = np.asarray(max_PSI_compactODEsize200, dtype=np.float64)
min_PSI_compactODEsize200 = np.asarray(min_PSI_compactODEsize200, dtype=np.float64)

time_years_compactODEsize200 = time_array_compactODEsize200 / (365.2425*24*3600)

# %%
time_list_compactODEsize400 = []
dt_array_compactODEsize400 = []
V_array_compactODEsize400 = []
F_array_compactODEsize400 = []
rhs_count_array_compactODEsize400 = []
ksp_count_array_compactODEsize400 = []
max_S_compactODEsize400 = []
min_S_compactODEsize400 = []
max_PSI_compactODEsize400 = []
min_PSI_compactODEsize400 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size400__AS_compactode_5dp_Satol1e-08__EQ_compactode_5dp_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_compactODEsize400.append(time)
            dt_array_compactODEsize400.append(dt)

            V_array_compactODEsize400.append(row['Vmax'])
            F_array_compactODEsize400.append(row['fmax'])
            rhs_count_array_compactODEsize400.append(row['count_rhs'])
            ksp_count_array_compactODEsize400.append(row['KSP_iteration'])
            max_S_compactODEsize400.append(row['maxS'])
            min_S_compactODEsize400.append(row['minS'])
            max_PSI_compactODEsize400.append(row['maxPSI'])
            min_PSI_compactODEsize400.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_compactODEsize400 = row['t_init']
            if (row['t_solve']):
                solve_time_compactODEsize400 = row['t_solve']
            if (row['t_total']):
                total_time_compactODEsize400 = row['t_total']

time_array_compactODEsize400 = np.asarray(time_list_compactODEsize400, dtype=np.float64)
dt_array_compactODEsize400 = np.asarray(dt_array_compactODEsize400, dtype=np.float64)
V_array_compactODEsize400 = np.asarray(V_array_compactODEsize400, dtype=np.float64)
F_array_compactODEsize400 = np.asarray(F_array_compactODEsize400, dtype=np.float64)
rhs_count_array_compactODEsize400 = np.asarray(rhs_count_array_compactODEsize400, dtype=np.float64)
ksp_count_array_compactODEsize400 = np.asarray(ksp_count_array_compactODEsize400, dtype=np.float64)
max_S_compactODEsize400 = np.asarray(max_S_compactODEsize400, dtype=np.float64)
min_S_compactODEsize400 = np.asarray(min_S_compactODEsize400, dtype=np.float64)
max_PSI_compactODEsize400 = np.asarray(max_PSI_compactODEsize400, dtype=np.float64)
min_PSI_compactODEsize400 = np.asarray(min_PSI_compactODEsize400, dtype=np.float64)

time_years_compactODEsize400 = time_array_compactODEsize400 / (365.2425*24*3600)

# %%
time_list_BDFcompactODEsize52 = []
dt_array_BDFcompactODEsize52 = []
V_array_BDFcompactODEsize52 = []
F_array_BDFcompactODEsize52 = []
rhs_count_array_BDFcompactODEsize52 = []
ksp_count_array_BDFcompactODEsize52 = []
max_S_BDFcompactODEsize52 = []
min_S_BDFcompactODEsize52 = []
max_PSI_BDFcompactODEsize52 = []
min_PSI_BDFcompactODEsize52 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size52__AS_compactode_BDF0_sor-gmres_Satol1e-08__EQ_compactode_BDF0_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_BDFcompactODEsize52.append(time)
            dt_array_BDFcompactODEsize52.append(dt)

            V_array_BDFcompactODEsize52.append(row['Vmax'])
            F_array_BDFcompactODEsize52.append(row['fmax'])
            rhs_count_array_BDFcompactODEsize52.append(row['count_rhs'])
            ksp_count_array_BDFcompactODEsize52.append(row['KSP_iteration'])
            max_S_BDFcompactODEsize52.append(row['maxS'])
            min_S_BDFcompactODEsize52.append(row['minS'])
            max_PSI_BDFcompactODEsize52.append(row['maxPSI'])
            min_PSI_BDFcompactODEsize52.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_BDFcompactODEsize52 = row['t_init']
            if (row['t_solve']):
                solve_time_BDFcompactODEsize52 = row['t_solve']
            if (row['t_total']):
                total_time_BDFcompactODEsize52 = row['t_total']

time_array_BDFcompactODEsize52 = np.asarray(time_list_BDFcompactODEsize52, dtype=np.float64)
dt_array_BDFcompactODEsize52 = np.asarray(dt_array_BDFcompactODEsize52, dtype=np.float64)
V_array_BDFcompactODEsize52 = np.asarray(V_array_BDFcompactODEsize52, dtype=np.float64)
F_array_BDFcompactODEsize52 = np.asarray(F_array_BDFcompactODEsize52, dtype=np.float64)
rhs_count_array_BDFcompactODEsize52 = np.asarray(rhs_count_array_BDFcompactODEsize52, dtype=np.float64)
ksp_count_array_BDFcompactODEsize52 = np.asarray(ksp_count_array_BDFcompactODEsize52, dtype=np.float64)
max_S_BDFcompactODEsize52 = np.asarray(max_S_BDFcompactODEsize52, dtype=np.float64)
min_S_BDFcompactODEsize52 = np.asarray(min_S_BDFcompactODEsize52, dtype=np.float64)
max_PSI_BDFcompactODEsize52 = np.asarray(max_PSI_BDFcompactODEsize52, dtype=np.float64)
min_PSI_BDFcompactODEsize52 = np.asarray(min_PSI_BDFcompactODEsize52, dtype=np.float64)

time_years_BDFcompactODEsize52 = time_array_BDFcompactODEsize52 / (365.2425*24*3600)

# %%
time_list_BDFcompactODEsize101 = []
dt_array_BDFcompactODEsize101 = []
V_array_BDFcompactODEsize101 = []
F_array_BDFcompactODEsize101 = []
rhs_count_array_BDFcompactODEsize101 = []
ksp_count_array_BDFcompactODEsize101 = []
max_S_BDFcompactODEsize101 = []
min_S_BDFcompactODEsize101 = []
max_PSI_BDFcompactODEsize101 = []
min_PSI_BDFcompactODEsize101 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_compactode_BDF0_sor-gmres_Satol1e-08__EQ_compactode_BDF0_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_BDFcompactODEsize101.append(time)
            dt_array_BDFcompactODEsize101.append(dt)

            V_array_BDFcompactODEsize101.append(row['Vmax'])
            F_array_BDFcompactODEsize101.append(row['fmax'])
            rhs_count_array_BDFcompactODEsize101.append(row['count_rhs'])
            ksp_count_array_BDFcompactODEsize101.append(row['KSP_iteration'])
            max_S_BDFcompactODEsize101.append(row['maxS'])
            min_S_BDFcompactODEsize101.append(row['minS'])
            max_PSI_BDFcompactODEsize101.append(row['maxPSI'])
            min_PSI_BDFcompactODEsize101.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_BDFcompactODEsize101 = row['t_init']
            if (row['t_solve']):
                solve_time_BDFcompactODEsize101 = row['t_solve']
            if (row['t_total']):
                total_time_BDFcompactODEsize101 = row['t_total']

time_array_BDFcompactODEsize101 = np.asarray(time_list_BDFcompactODEsize101, dtype=np.float64)
dt_array_BDFcompactODEsize101 = np.asarray(dt_array_BDFcompactODEsize101, dtype=np.float64)
V_array_BDFcompactODEsize101 = np.asarray(V_array_BDFcompactODEsize101, dtype=np.float64)
F_array_BDFcompactODEsize101 = np.asarray(F_array_BDFcompactODEsize101, dtype=np.float64)
rhs_count_array_BDFcompactODEsize101 = np.asarray(rhs_count_array_BDFcompactODEsize101, dtype=np.float64)
ksp_count_array_BDFcompactODEsize101 = np.asarray(ksp_count_array_BDFcompactODEsize101, dtype=np.float64)
max_S_BDFcompactODEsize101 = np.asarray(max_S_BDFcompactODEsize101, dtype=np.float64)
min_S_BDFcompactODEsize101 = np.asarray(min_S_BDFcompactODEsize101, dtype=np.float64)
max_PSI_BDFcompactODEsize101 = np.asarray(max_PSI_BDFcompactODEsize101, dtype=np.float64)
min_PSI_BDFcompactODEsize101 = np.asarray(min_PSI_BDFcompactODEsize101, dtype=np.float64)

time_years_BDFcompactODEsize101 = time_array_BDFcompactODEsize101 / (365.2425*24*3600)

# %%
time_list_BDFcompactODEsize200 = []
dt_array_BDFcompactODEsize200 = []
V_array_BDFcompactODEsize200 = []
F_array_BDFcompactODEsize200 = []
rhs_count_array_BDFcompactODEsize200 = []
ksp_count_array_BDFcompactODEsize200 = []
max_S_BDFcompactODEsize200 = []
min_S_BDFcompactODEsize200 = []
max_PSI_BDFcompactODEsize200 = []
min_PSI_BDFcompactODEsize200 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size200__AS_compactode_BDF0_sor-gmres_Satol1e-08__EQ_compactode_BDF0_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_BDFcompactODEsize200.append(time)
            dt_array_BDFcompactODEsize200.append(dt)

            V_array_BDFcompactODEsize200.append(row['Vmax'])
            F_array_BDFcompactODEsize200.append(row['fmax'])
            rhs_count_array_BDFcompactODEsize200.append(row['count_rhs'])
            ksp_count_array_BDFcompactODEsize200.append(row['KSP_iteration'])
            max_S_BDFcompactODEsize200.append(row['maxS'])
            min_S_BDFcompactODEsize200.append(row['minS'])
            max_PSI_BDFcompactODEsize200.append(row['maxPSI'])
            min_PSI_BDFcompactODEsize200.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_BDFcompactODEsize200 = row['t_init']
            if (row['t_solve']):
                solve_time_BDFcompactODEsize200 = row['t_solve']
            if (row['t_total']):
                total_time_BDFcompactODEsize200 = row['t_total']

time_array_BDFcompactODEsize200 = np.asarray(time_list_BDFcompactODEsize200, dtype=np.float64)
dt_array_BDFcompactODEsize200 = np.asarray(dt_array_BDFcompactODEsize200, dtype=np.float64)
V_array_BDFcompactODEsize200 = np.asarray(V_array_BDFcompactODEsize200, dtype=np.float64)
F_array_BDFcompactODEsize200 = np.asarray(F_array_BDFcompactODEsize200, dtype=np.float64)
rhs_count_array_BDFcompactODEsize200 = np.asarray(rhs_count_array_BDFcompactODEsize200, dtype=np.float64)
ksp_count_array_BDFcompactODEsize200 = np.asarray(ksp_count_array_BDFcompactODEsize200, dtype=np.float64)
max_S_BDFcompactODEsize200 = np.asarray(max_S_BDFcompactODEsize200, dtype=np.float64)
min_S_BDFcompactODEsize200 = np.asarray(min_S_BDFcompactODEsize200, dtype=np.float64)
max_PSI_BDFcompactODEsize200 = np.asarray(max_PSI_BDFcompactODEsize200, dtype=np.float64)
min_PSI_BDFcompactODEsize200 = np.asarray(min_PSI_BDFcompactODEsize200, dtype=np.float64)

time_years_BDFcompactODEsize200 = time_array_BDFcompactODEsize200 / (365.2425*24*3600)

# %%
time_list_BDFcompactODEsize400 = []
dt_array_BDFcompactODEsize400 = []
V_array_BDFcompactODEsize400 = []
F_array_BDFcompactODEsize400 = []
rhs_count_array_BDFcompactODEsize400 = []
ksp_count_array_BDFcompactODEsize400 = []
max_S_BDFcompactODEsize400 = []
min_S_BDFcompactODEsize400 = []
max_PSI_BDFcompactODEsize400 = []
min_PSI_BDFcompactODEsize400 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size400__AS_compactode_BDF0_sor-gmres_Satol1e-08__EQ_compactode_BDF0_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_BDFcompactODEsize400.append(time)
            dt_array_BDFcompactODEsize400.append(dt)

            V_array_BDFcompactODEsize400.append(row['Vmax'])
            F_array_BDFcompactODEsize400.append(row['fmax'])
            rhs_count_array_BDFcompactODEsize400.append(row['count_rhs'])
            ksp_count_array_BDFcompactODEsize400.append(row['KSP_iteration'])
            max_S_BDFcompactODEsize400.append(row['maxS'])
            min_S_BDFcompactODEsize400.append(row['minS'])
            max_PSI_BDFcompactODEsize400.append(row['maxPSI'])
            min_PSI_BDFcompactODEsize400.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_BDFcompactODEsize400 = row['t_init']
            if (row['t_solve']):
                solve_time_BDFcompactODEsize400 = row['t_solve']
            if (row['t_total']):
                total_time_BDFcompactODEsize400 = row['t_total']

time_array_BDFcompactODEsize400 = np.asarray(time_list_BDFcompactODEsize400, dtype=np.float64)
dt_array_BDFcompactODEsize400 = np.asarray(dt_array_BDFcompactODEsize400, dtype=np.float64)
V_array_BDFcompactODEsize400 = np.asarray(V_array_BDFcompactODEsize400, dtype=np.float64)
F_array_BDFcompactODEsize400 = np.asarray(F_array_BDFcompactODEsize400, dtype=np.float64)
rhs_count_array_BDFcompactODEsize400 = np.asarray(rhs_count_array_BDFcompactODEsize400, dtype=np.float64)
ksp_count_array_BDFcompactODEsize400 = np.asarray(ksp_count_array_BDFcompactODEsize400, dtype=np.float64)
max_S_BDFcompactODEsize400 = np.asarray(max_S_BDFcompactODEsize400, dtype=np.float64)
min_S_BDFcompactODEsize400 = np.asarray(min_S_BDFcompactODEsize400, dtype=np.float64)
max_PSI_BDFcompactODEsize400 = np.asarray(max_PSI_BDFcompactODEsize400, dtype=np.float64)
min_PSI_BDFcompactODEsize400 = np.asarray(min_PSI_BDFcompactODEsize400, dtype=np.float64)

time_years_BDFcompactODEsize400 = time_array_BDFcompactODEsize400 / (365.2425*24*3600)

# %%
time_list_extendedDAEsize52 = []
dt_array_extendedDAEsize52 = []
V_array_extendedDAEsize52 = []
F_array_extendedDAEsize52 = []
rhs_count_array_extendedDAEsize52 = []
ksp_count_array_extendedDAEsize52 = []
max_S_extendedDAEsize52 = []
min_S_extendedDAEsize52 = []
max_PSI_extendedDAEsize52 = []
min_PSI_extendedDAEsize52 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size52__AS_extendeddae_BDF0_sor-gmres_Satol1e-08__EQ_extendeddae_BDF0_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_extendedDAEsize52.append(time)
            dt_array_extendedDAEsize52.append(dt)

            V_array_extendedDAEsize52.append(row['Vmax'])
            F_array_extendedDAEsize52.append(row['fmax'])
            rhs_count_array_extendedDAEsize52.append(row['count_rhs'])
            ksp_count_array_extendedDAEsize52.append(row['KSP_iteration'])
            max_S_extendedDAEsize52.append(row['maxS'])
            min_S_extendedDAEsize52.append(row['minS'])
            max_PSI_extendedDAEsize52.append(row['maxPSI'])
            min_PSI_extendedDAEsize52.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_extendedDAEsize52 = row['t_init']
            if (row['t_solve']):
                solve_time_extendedDAEsize52 = row['t_solve']
            if (row['t_total']):
                total_time_extendedDAEsize52 = row['t_total']

time_array_extendedDAEsize52 = np.asarray(time_list_extendedDAEsize52, dtype=np.float64)
dt_array_extendedDAEsize52 = np.asarray(dt_array_extendedDAEsize52, dtype=np.float64)
V_array_extendedDAEsize52 = np.asarray(V_array_extendedDAEsize52, dtype=np.float64)
F_array_extendedDAEsize52 = np.asarray(F_array_extendedDAEsize52, dtype=np.float64)
rhs_count_array_extendedDAEsize52 = np.asarray(rhs_count_array_extendedDAEsize52, dtype=np.float64)
ksp_count_array_extendedDAEsize52 = np.asarray(ksp_count_array_extendedDAEsize52, dtype=np.float64)
max_S_extendedDAEsize52 = np.asarray(max_S_extendedDAEsize52, dtype=np.float64)
min_S_extendedDAEsize52 = np.asarray(min_S_extendedDAEsize52, dtype=np.float64)
max_PSI_extendedDAEsize52 = np.asarray(max_PSI_extendedDAEsize52, dtype=np.float64)
min_PSI_extendedDAEsize52 = np.asarray(min_PSI_extendedDAEsize52, dtype=np.float64)

time_years_extendedDAEsize52 = time_array_extendedDAEsize52 / (365.2425*24*3600)

# %%
time_list_extendedDAEsize101 = []
dt_array_extendedDAEsize101 = []
V_array_extendedDAEsize101 = []
F_array_extendedDAEsize101 = []
rhs_count_array_extendedDAEsize101 = []
ksp_count_array_extendedDAEsize101 = []
max_S_extendedDAEsize101 = []
min_S_extendedDAEsize101 = []
max_PSI_extendedDAEsize101 = []
min_PSI_extendedDAEsize101 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_extendeddae_BDF0_sor-gmres_Satol1e-08__EQ_extendeddae_BDF0_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_extendedDAEsize101.append(time)
            dt_array_extendedDAEsize101.append(dt)

            V_array_extendedDAEsize101.append(row['Vmax'])
            F_array_extendedDAEsize101.append(row['fmax'])
            rhs_count_array_extendedDAEsize101.append(row['count_rhs'])
            ksp_count_array_extendedDAEsize101.append(row['KSP_iteration'])
            max_S_extendedDAEsize101.append(row['maxS'])
            min_S_extendedDAEsize101.append(row['minS'])
            max_PSI_extendedDAEsize101.append(row['maxPSI'])
            min_PSI_extendedDAEsize101.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_extendedDAEsize101 = row['t_init']
            if (row['t_solve']):
                solve_time_extendedDAEsize101 = row['t_solve']
            if (row['t_total']):
                total_time_extendedDAEsize101 = row['t_total']

time_array_extendedDAEsize101 = np.asarray(time_list_extendedDAEsize101, dtype=np.float64)
dt_array_extendedDAEsize101 = np.asarray(dt_array_extendedDAEsize101, dtype=np.float64)
V_array_extendedDAEsize101 = np.asarray(V_array_extendedDAEsize101, dtype=np.float64)
F_array_extendedDAEsize101 = np.asarray(F_array_extendedDAEsize101, dtype=np.float64)
rhs_count_array_extendedDAEsize101 = np.asarray(rhs_count_array_extendedDAEsize101, dtype=np.float64)
ksp_count_array_extendedDAEsize101 = np.asarray(ksp_count_array_extendedDAEsize101, dtype=np.float64)
max_S_extendedDAEsize101 = np.asarray(max_S_extendedDAEsize101, dtype=np.float64)
min_S_extendedDAEsize101 = np.asarray(min_S_extendedDAEsize101, dtype=np.float64)
max_PSI_extendedDAEsize101 = np.asarray(max_PSI_extendedDAEsize101, dtype=np.float64)
min_PSI_extendedDAEsize101 = np.asarray(min_PSI_extendedDAEsize101, dtype=np.float64)

time_years_extendedDAEsize101 = time_array_extendedDAEsize101 / (365.2425*24*3600)

# %%
time_list_extendedDAEsize200 = []
dt_array_extendedDAEsize200 = []
V_array_extendedDAEsize200 = []
F_array_extendedDAEsize200 = []
rhs_count_array_extendedDAEsize200 = []
ksp_count_array_extendedDAEsize200 = []
max_S_extendedDAEsize200 = []
min_S_extendedDAEsize200 = []
max_PSI_extendedDAEsize200 = []
min_PSI_extendedDAEsize200 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size200__AS_extendeddae_BDF0_sor-gmres_Satol1e-08__EQ_extendeddae_BDF0_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_extendedDAEsize200.append(time)
            dt_array_extendedDAEsize200.append(dt)

            V_array_extendedDAEsize200.append(row['Vmax'])
            F_array_extendedDAEsize200.append(row['fmax'])
            rhs_count_array_extendedDAEsize200.append(row['count_rhs'])
            ksp_count_array_extendedDAEsize200.append(row['KSP_iteration'])
            max_S_extendedDAEsize200.append(row['maxS'])
            min_S_extendedDAEsize200.append(row['minS'])
            max_PSI_extendedDAEsize200.append(row['maxPSI'])
            min_PSI_extendedDAEsize200.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_extendedDAEsize200 = row['t_init']
            if (row['t_solve']):
                solve_time_extendedDAEsize200 = row['t_solve']
            if (row['t_total']):
                total_time_extendedDAEsize200 = row['t_total']

time_array_extendedDAEsize200 = np.asarray(time_list_extendedDAEsize200, dtype=np.float64)
dt_array_extendedDAEsize200 = np.asarray(dt_array_extendedDAEsize200, dtype=np.float64)
V_array_extendedDAEsize200 = np.asarray(V_array_extendedDAEsize200, dtype=np.float64)
F_array_extendedDAEsize200 = np.asarray(F_array_extendedDAEsize200, dtype=np.float64)
rhs_count_array_extendedDAEsize200 = np.asarray(rhs_count_array_extendedDAEsize200, dtype=np.float64)
ksp_count_array_extendedDAEsize200 = np.asarray(ksp_count_array_extendedDAEsize200, dtype=np.float64)
max_S_sizeextendedDAE200 = np.asarray(max_S_extendedDAEsize200, dtype=np.float64)
min_S_extendedDAEsize200 = np.asarray(min_S_extendedDAEsize200, dtype=np.float64)
max_PSI_extendedDAEsize200 = np.asarray(max_PSI_extendedDAEsize200, dtype=np.float64)
min_PSI_extendedDAEsize200 = np.asarray(min_PSI_extendedDAEsize200, dtype=np.float64)

time_years_extendedDAEsize200 = time_array_extendedDAEsize200 / (365.2425*24*3600)

# %%
time_list_extendedDAEsize400 = []
dt_array_extendedDAEsize400 = []
V_array_extendedDAEsize400 = []
F_array_extendedDAEsize400 = []
rhs_count_array_extendedDAEsize400 = []
ksp_count_array_extendedDAEsize400 = []
max_S_extendedDAEsize400 = []
min_S_extendedDAEsize400 = []
max_PSI_extendedDAEsize400 = []
min_PSI_extendedDAEsize400 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size400__AS_extendeddae_BDF0_sor-gmres_Satol1e-08__EQ_extendeddae_BDF0_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_extendedDAEsize400.append(time)
            dt_array_extendedDAEsize400.append(dt)

            V_array_extendedDAEsize400.append(row['Vmax'])
            F_array_extendedDAEsize400.append(row['fmax'])
            rhs_count_array_extendedDAEsize400.append(row['count_rhs'])
            ksp_count_array_extendedDAEsize400.append(row['KSP_iteration'])
            max_S_extendedDAEsize400.append(row['maxS'])
            min_S_extendedDAEsize400.append(row['minS'])
            max_PSI_extendedDAEsize400.append(row['maxPSI'])
            min_PSI_extendedDAEsize400.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_extendedDAEsize400 = row['t_init']
            if (row['t_solve']):
                solve_time_extendedDAEsize400 = row['t_solve']
            if (row['t_total']):
                total_time_extendedDAEsize400 = row['t_total']

time_array_extendedDAEsize400 = np.asarray(time_list_extendedDAEsize400, dtype=np.float64)
dt_array_extendedDAEsize400 = np.asarray(dt_array_extendedDAEsize400, dtype=np.float64)
V_array_extendedDAEsize400 = np.asarray(V_array_extendedDAEsize400, dtype=np.float64)
F_array_extendedDAEsize400 = np.asarray(F_array_extendedDAEsize400, dtype=np.float64)
rhs_count_array_extendedDAEsize400 = np.asarray(rhs_count_array_extendedDAEsize400, dtype=np.float64)
ksp_count_array_extendedDAEsize400 = np.asarray(ksp_count_array_extendedDAEsize400, dtype=np.float64)
max_S_extendedDAEsize400 = np.asarray(max_S_extendedDAEsize400, dtype=np.float64)
min_S_extendedDAEsize400 = np.asarray(min_S_extendedDAEsize400, dtype=np.float64)
max_PSI_extendedDAEsize400 = np.asarray(max_PSI_extendedDAEsize400, dtype=np.float64)
min_PSI_extendedDAEsize400 = np.asarray(min_PSI_extendedDAEsize400, dtype=np.float64)

time_years_extendedDAEsize400 = time_array_extendedDAEsize400 / (365.2425*24*3600)

# %%
time_list_extendedODEsize52 = []
dt_array_extendedODEsize52 = []
V_array_extendedODEsize52 = []
F_array_extendedODEsize52 = []
rhs_count_array_extendedODEsize52 = []
ksp_count_array_extendedODEsize52 = []
max_S_extendedODEsize52 = []
min_S_extendedODEsize52 = []
max_PSI_extendedODEsize52 = []
min_PSI_extendedODEsize52 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size52__AS_extendedode_5dp_Vrtol1e-08__EQ_extendedode_5dp_Vrtol1e-07.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_extendedODEsize52.append(time)
            dt_array_extendedODEsize52.append(dt)

            V_array_extendedODEsize52.append(row['Vmax'])
            F_array_extendedODEsize52.append(row['fmax'])
            rhs_count_array_extendedODEsize52.append(row['count_rhs'])
            ksp_count_array_extendedODEsize52.append(row['KSP_iteration'])
            max_S_extendedODEsize52.append(row['maxS'])
            min_S_extendedODEsize52.append(row['minS'])
            max_PSI_extendedODEsize52.append(row['maxPSI'])
            min_PSI_extendedODEsize52.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_extendedODEsize52 = row['t_init']
            if (row['t_solve']):
                solve_time_extendedODEsize52 = row['t_solve']
            if (row['t_total']):
                total_time_extendedODEsize52 = row['t_total']

time_array_extendedODEsize52 = np.asarray(time_list_extendedODEsize52, dtype=np.float64)
dt_array_extendedODEsize52 = np.asarray(dt_array_extendedODEsize52, dtype=np.float64)
V_array_extendedODEsize52 = np.asarray(V_array_extendedODEsize52, dtype=np.float64)
F_array_extendedODEsize52 = np.asarray(F_array_extendedODEsize52, dtype=np.float64)
rhs_count_array_extendedODEsize52 = np.asarray(rhs_count_array_extendedODEsize52, dtype=np.float64)
ksp_count_array_extendedODEsize52 = np.asarray(ksp_count_array_extendedODEsize52, dtype=np.float64)
max_S_extendedODEsize52 = np.asarray(max_S_extendedODEsize52, dtype=np.float64)
min_S_extendedODEsize52 = np.asarray(min_S_extendedODEsize52, dtype=np.float64)
max_PSI_extendedODEsize52 = np.asarray(max_PSI_extendedODEsize52, dtype=np.float64)
min_PSI_extendedODEsize52 = np.asarray(min_PSI_extendedODEsize52, dtype=np.float64)

time_years_extendedODEsize52 = time_array_extendedODEsize52 / (365.2425*24*3600)

# %%
time_list_extendedODEsize101 = []
dt_array_extendedODEsize101 = []
V_array_extendedODEsize101 = []
F_array_extendedODEsize101 = []
rhs_count_array_extendedODEsize101 = []
ksp_count_array_extendedODEsize101 = []
max_S_extendedODEsize101 = []
min_S_extendedODEsize101 = []
max_PSI_extendedODEsize101 = []
min_PSI_extendedODEsize101 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_extendedode_5dp_Vrtol1e-08__EQ_extendedode_5dp_Vrtol1e-07.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_extendedODEsize101.append(time)
            dt_array_extendedODEsize101.append(dt)

            V_array_extendedODEsize101.append(row['Vmax'])
            F_array_extendedODEsize101.append(row['fmax'])
            rhs_count_array_extendedODEsize101.append(row['count_rhs'])
            ksp_count_array_extendedODEsize101.append(row['KSP_iteration'])
            max_S_extendedODEsize101.append(row['maxS'])
            min_S_extendedODEsize101.append(row['minS'])
            max_PSI_extendedODEsize101.append(row['maxPSI'])
            min_PSI_extendedODEsize101.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_extendedODEsize101 = row['t_init']
            if (row['t_solve']):
                solve_time_extendedODEsize101 = row['t_solve']
            if (row['t_total']):
                total_time_extendedODEsize101 = row['t_total']

time_array_extendedODEsize101 = np.asarray(time_list_extendedODEsize101, dtype=np.float64)
dt_array_extendedODEsize101 = np.asarray(dt_array_extendedODEsize101, dtype=np.float64)
V_array_extendedODEsize101 = np.asarray(V_array_extendedODEsize101, dtype=np.float64)
F_array_extendedODEsize101 = np.asarray(F_array_extendedODEsize101, dtype=np.float64)
rhs_count_array_extendedODEsize101 = np.asarray(rhs_count_array_extendedODEsize101, dtype=np.float64)
ksp_count_array_extendedODEsize101 = np.asarray(ksp_count_array_extendedODEsize101, dtype=np.float64)
max_S_extendedODEsize101 = np.asarray(max_S_extendedODEsize101, dtype=np.float64)
min_S_extendedODEsize101 = np.asarray(min_S_extendedODEsize101, dtype=np.float64)
max_PSI_extendedODEsize101 = np.asarray(max_PSI_extendedODEsize101, dtype=np.float64)
min_PSI_extendedODEsize101 = np.asarray(min_PSI_extendedODEsize101, dtype=np.float64)

time_years_extendedODEsize101 = time_array_extendedODEsize101 / (365.2425*24*3600)

# %%
time_list_extendedODEsize200 = []
dt_array_extendedODEsize200 = []
V_array_extendedODEsize200 = []
F_array_extendedODEsize200 = []
rhs_count_array_extendedODEsize200 = []
ksp_count_array_extendedODEsize200 = []
max_S_extendedODEsize200 = []
min_S_extendedODEsize200 = []
max_PSI_extendedODEsize200 = []
min_PSI_extendedODEsize200 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size200__AS_extendedode_5dp_Vrtol1e-08__EQ_extendedode_5dp_Vrtol1e-07.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_extendedODEsize200.append(time)
            dt_array_extendedODEsize200.append(dt)

            V_array_extendedODEsize200.append(row['Vmax'])
            F_array_extendedODEsize200.append(row['fmax'])
            rhs_count_array_extendedODEsize200.append(row['count_rhs'])
            ksp_count_array_extendedODEsize200.append(row['KSP_iteration'])
            max_S_extendedODEsize200.append(row['maxS'])
            min_S_extendedODEsize200.append(row['minS'])
            max_PSI_extendedODEsize200.append(row['maxPSI'])
            min_PSI_extendedODEsize200.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_extendedODEsize200 = row['t_init']
            if (row['t_solve']):
                solve_time_extendedODEsize200 = row['t_solve']
            if (row['t_total']):
                total_time_extendedODEsize200 = row['t_total']

time_array_extendedODEsize200 = np.asarray(time_list_extendedODEsize200, dtype=np.float64)
dt_array_extendedODEsize200 = np.asarray(dt_array_extendedODEsize200, dtype=np.float64)
V_array_extendedODEsize200 = np.asarray(V_array_extendedODEsize200, dtype=np.float64)
F_array_extendedODEsize200 = np.asarray(F_array_extendedODEsize200, dtype=np.float64)
rhs_count_array_extendedODEsize200 = np.asarray(rhs_count_array_extendedODEsize200, dtype=np.float64)
ksp_count_array_extendedODEsize200 = np.asarray(ksp_count_array_extendedODEsize200, dtype=np.float64)
max_S_extendedODEsize200 = np.asarray(max_S_extendedODEsize200, dtype=np.float64)
min_S_extendedODEsize200 = np.asarray(min_S_extendedODEsize200, dtype=np.float64)
max_PSI_extendedODEsize200 = np.asarray(max_PSI_extendedODEsize200, dtype=np.float64)
min_PSI_extendedODEsize200 = np.asarray(min_PSI_extendedODEsize200, dtype=np.float64)

time_years_extendedODEsize200 = time_array_extendedODEsize200 / (365.2425*24*3600)

# %%
time_list_extendedODEsize400 = []
dt_array_extendedODEsize400 = []
V_array_extendedODEsize400 = []
F_array_extendedODEsize400 = []
rhs_count_array_extendedODEsize400 = []
ksp_count_array_extendedODEsize400 = []
max_S_extendedODEsize400 = []
min_S_extendedODEsize400 = []
max_PSI_extendedODEsize400 = []
min_PSI_extendedODEsize400 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size400__AS_extendedode_5dp_Vrtol1e-08__EQ_extendedode_5dp_Vrtol1e-07.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_extendedODEsize400.append(time)
            dt_array_extendedODEsize400.append(dt)

            V_array_extendedODEsize400.append(row['Vmax'])
            F_array_extendedODEsize400.append(row['fmax'])
            rhs_count_array_extendedODEsize400.append(row['count_rhs'])
            ksp_count_array_extendedODEsize400.append(row['KSP_iteration'])
            max_S_extendedODEsize400.append(row['maxS'])
            min_S_extendedODEsize400.append(row['minS'])
            max_PSI_extendedODEsize400.append(row['maxPSI'])
            min_PSI_extendedODEsize400.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_extendedODEsize400 = row['t_init']
            if (row['t_solve']):
                solve_time_extendedODEsize400 = row['t_solve']
            if (row['t_total']):
                total_time_extendedODEsize400 = row['t_total']

time_array_extendedODEsize400 = np.asarray(time_list_extendedODEsize400, dtype=np.float64)
dt_array_extendedODEsize400 = np.asarray(dt_array_extendedODEsize400, dtype=np.float64)
V_array_extendedODEsize400 = np.asarray(V_array_extendedODEsize400, dtype=np.float64)
F_array_extendedODEsize400 = np.asarray(F_array_extendedODEsize400, dtype=np.float64)
rhs_count_array_extendedODEsize400 = np.asarray(rhs_count_array_extendedODEsize400, dtype=np.float64)
ksp_count_array_extendedODEsize400 = np.asarray(ksp_count_array_extendedODEsize400, dtype=np.float64)
max_S_extendedODEsize400 = np.asarray(max_S_extendedODEsize400, dtype=np.float64)
min_S_extendedODEsize400 = np.asarray(min_S_extendedODEsize400, dtype=np.float64)
max_PSI_extendedODEsize400 = np.asarray(max_PSI_extendedODEsize400, dtype=np.float64)
min_PSI_extendedODEsize400 = np.asarray(min_PSI_extendedODEsize400, dtype=np.float64)

time_years_extendedODEsize400 = time_array_extendedODEsize400 / (365.2425*24*3600)

# %%
time_list_BDFextendedODEsize52 = []
dt_array_BDFextendedODEsize52 = []
V_array_BDFextendedODEsize52 = []
F_array_BDFextendedODEsize52 = []
rhs_count_array_BDFextendedODEsize52 = []
ksp_count_array_BDFextendedODEsize52 = []
max_S_BDFextendedODEsize52 = []
min_S_BDFextendedODEsize52 = []
max_PSI_BDFextendedODEsize52 = []
min_PSI_BDFextendedODEsize52 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size52__AS_extendedode_BDF0_sor-gmres_Vrtol1e-08__EQ_extendedode_BDF0_sor-gmres_Vrtol1e-07.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_BDFextendedODEsize52.append(time)
            dt_array_BDFextendedODEsize52.append(dt)

            V_array_BDFextendedODEsize52.append(row['Vmax'])
            F_array_BDFextendedODEsize52.append(row['fmax'])
            rhs_count_array_BDFextendedODEsize52.append(row['count_rhs'])
            ksp_count_array_BDFextendedODEsize52.append(row['KSP_iteration'])
            max_S_BDFextendedODEsize52.append(row['maxS'])
            min_S_BDFextendedODEsize52.append(row['minS'])
            max_PSI_BDFextendedODEsize52.append(row['maxPSI'])
            min_PSI_BDFextendedODEsize52.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_BDFextendedODEsize52 = row['t_init']
            if (row['t_solve']):
                solve_time_BDFextendedODEsize52 = row['t_solve']
            if (row['t_total']):
                total_time_BDFextendedODEsize52 = row['t_total']

time_array_BDFextendedODEsize52 = np.asarray(time_list_BDFextendedODEsize52, dtype=np.float64)
dt_array_BDFextendedODEsize52 = np.asarray(dt_array_BDFextendedODEsize52, dtype=np.float64)
V_array_BDFextendedODEsize52 = np.asarray(V_array_BDFextendedODEsize52, dtype=np.float64)
F_array_BDFextendedODEsize52 = np.asarray(F_array_BDFextendedODEsize52, dtype=np.float64)
rhs_count_array_BDFextendedODEsize52 = np.asarray(rhs_count_array_BDFextendedODEsize52, dtype=np.float64)
ksp_count_array_BDFextendedODEsize52 = np.asarray(ksp_count_array_BDFextendedODEsize52, dtype=np.float64)
max_S_BDFextendedODEsize52 = np.asarray(max_S_BDFextendedODEsize52, dtype=np.float64)
min_S_BDFextendedODEsize52 = np.asarray(min_S_BDFextendedODEsize52, dtype=np.float64)
max_PSI_BDFextendedODEsize52 = np.asarray(max_PSI_BDFextendedODEsize52, dtype=np.float64)
min_PSI_BDFextendedODEsize52 = np.asarray(min_PSI_BDFextendedODEsize52, dtype=np.float64)

time_years_BDFextendedODEsize52 = time_array_BDFextendedODEsize52 / (365.2425*24*3600)

# %%
time_list_BDFextendedODEsize52 = []
dt_array_BDFextendedODEsize52 = []
V_array_BDFextendedODEsize52 = []
F_array_BDFextendedODEsize52 = []
rhs_count_array_BDFextendedODEsize52 = []
ksp_count_array_BDFextendedODEsize52 = []
max_S_BDFextendedODEsize52 = []
min_S_BDFextendedODEsize52 = []
max_PSI_BDFextendedODEsize52 = []
min_PSI_BDFextendedODEsize52 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size52__AS_extendedode_BDF0_sor-gmres_Vrtol1e-08__EQ_extendedode_BDF0_sor-gmres_Vrtol1e-07.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_BDFextendedODEsize52.append(time)
            dt_array_BDFextendedODEsize52.append(dt)

            V_array_BDFextendedODEsize52.append(row['Vmax'])
            F_array_BDFextendedODEsize52.append(row['fmax'])
            rhs_count_array_BDFextendedODEsize52.append(row['count_rhs'])
            ksp_count_array_BDFextendedODEsize52.append(row['KSP_iteration'])
            max_S_BDFextendedODEsize52.append(row['maxS'])
            min_S_BDFextendedODEsize52.append(row['minS'])
            max_PSI_BDFextendedODEsize52.append(row['maxPSI'])
            min_PSI_BDFextendedODEsize52.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_BDFextendedODEsize52 = row['t_init']
            if (row['t_solve']):
                solve_time_BDFextendedODEsize52 = row['t_solve']
            if (row['t_total']):
                total_time_BDFextendedODEsize52 = row['t_total']

time_array_BDFextendedODEsize52 = np.asarray(time_list_BDFextendedODEsize52, dtype=np.float64)
dt_array_BDFextendedODEsize52 = np.asarray(dt_array_BDFextendedODEsize52, dtype=np.float64)
V_array_BDFextendedODEsize52 = np.asarray(V_array_BDFextendedODEsize52, dtype=np.float64)
F_array_BDFextendedODEsize52 = np.asarray(F_array_BDFextendedODEsize52, dtype=np.float64)
rhs_count_array_BDFextendedODEsize52 = np.asarray(rhs_count_array_BDFextendedODEsize52, dtype=np.float64)
ksp_count_array_BDFextendedODEsize52 = np.asarray(ksp_count_array_BDFextendedODEsize52, dtype=np.float64)
max_S_BDFextendedODEsize52 = np.asarray(max_S_BDFextendedODEsize52, dtype=np.float64)
min_S_BDFextendedODEsize52 = np.asarray(min_S_BDFextendedODEsize52, dtype=np.float64)
max_PSI_BDFextendedODEsize52 = np.asarray(max_PSI_BDFextendedODEsize52, dtype=np.float64)
min_PSI_BDFextendedODEsize52 = np.asarray(min_PSI_BDFextendedODEsize52, dtype=np.float64)

time_years_BDFextendedODEsize52 = time_array_BDFextendedODEsize52 / (365.2425*24*3600)

# %%
time_list_BDFextendedODEsize101 = []
dt_array_BDFextendedODEsize101 = []
V_array_BDFextendedODEsize101 = []
F_array_BDFextendedODEsize101 = []
rhs_count_array_BDFextendedODEsize101 = []
ksp_count_array_BDFextendedODEsize101 = []
max_S_BDFextendedODEsize101 = []
min_S_BDFextendedODEsize101 = []
max_PSI_BDFextendedODEsize101 = []
min_PSI_BDFextendedODEsize101 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_extendedode_BDF0_sor-gmres_Vrtol1e-08__EQ_extendedode_BDF0_sor-gmres_Vrtol1e-07.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_BDFextendedODEsize101.append(time)
            dt_array_BDFextendedODEsize101.append(dt)

            V_array_BDFextendedODEsize101.append(row['Vmax'])
            F_array_BDFextendedODEsize101.append(row['fmax'])
            rhs_count_array_BDFextendedODEsize101.append(row['count_rhs'])
            ksp_count_array_BDFextendedODEsize101.append(row['KSP_iteration'])
            max_S_BDFextendedODEsize101.append(row['maxS'])
            min_S_BDFextendedODEsize101.append(row['minS'])
            max_PSI_BDFextendedODEsize101.append(row['maxPSI'])
            min_PSI_BDFextendedODEsize101.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_BDFextendedODEsize101 = row['t_init']
            if (row['t_solve']):
                solve_time_BDFextendedODEsize101 = row['t_solve']
            if (row['t_total']):
                total_time_BDFextendedODEsize101 = row['t_total']

time_array_BDFextendedODEsize101 = np.asarray(time_list_BDFextendedODEsize101, dtype=np.float64)
dt_array_BDFextendedODEsize101 = np.asarray(dt_array_BDFextendedODEsize101, dtype=np.float64)
V_array_BDFextendedODEsize101 = np.asarray(V_array_BDFextendedODEsize101, dtype=np.float64)
F_array_BDFextendedODEsize101 = np.asarray(F_array_BDFextendedODEsize101, dtype=np.float64)
rhs_count_array_BDFextendedODEsize101 = np.asarray(rhs_count_array_BDFextendedODEsize101, dtype=np.float64)
ksp_count_array_BDFextendedODEsize101 = np.asarray(ksp_count_array_BDFextendedODEsize101, dtype=np.float64)
max_S_BDFextendedODEsize101 = np.asarray(max_S_BDFextendedODEsize101, dtype=np.float64)
min_S_BDFextendedODEsize101 = np.asarray(min_S_BDFextendedODEsize101, dtype=np.float64)
max_PSI_BDFextendedODEsize101 = np.asarray(max_PSI_BDFextendedODEsize101, dtype=np.float64)
min_PSI_BDFextendedODEsize101 = np.asarray(min_PSI_BDFextendedODEsize101, dtype=np.float64)

time_years_BDFextendedODEsize101 = time_array_BDFextendedODEsize101 / (365.2425*24*3600)

# %%
time_list_BDFextendedODEsize200 = []
dt_array_BDFextendedODEsize200 = []
V_array_BDFextendedODEsize200 = []
F_array_BDFextendedODEsize200 = []
rhs_count_array_BDFextendedODEsize200 = []
ksp_count_array_BDFextendedODEsize200 = []
max_S_BDFextendedODEsize200 = []
min_S_BDFextendedODEsize200 = []
max_PSI_BDFextendedODEsize200 = []
min_PSI_BDFextendedODEsize200 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size200__AS_extendedode_BDF0_sor-gmres_Vrtol1e-08__EQ_extendedode_BDF0_sor-gmres_Vrtol1e-07.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_BDFextendedODEsize200.append(time)
            dt_array_BDFextendedODEsize200.append(dt)

            V_array_BDFextendedODEsize200.append(row['Vmax'])
            F_array_BDFextendedODEsize200.append(row['fmax'])
            rhs_count_array_BDFextendedODEsize200.append(row['count_rhs'])
            ksp_count_array_BDFextendedODEsize200.append(row['KSP_iteration'])
            max_S_BDFextendedODEsize200.append(row['maxS'])
            min_S_BDFextendedODEsize200.append(row['minS'])
            max_PSI_BDFextendedODEsize200.append(row['maxPSI'])
            min_PSI_BDFextendedODEsize200.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_BDFextendedODEsize200 = row['t_init']
            if (row['t_solve']):
                solve_time_BDFextendedODEsize200 = row['t_solve']
            if (row['t_total']):
                total_time_BDFextendedODEsize200 = row['t_total']

time_array_BDFextendedODEsize200 = np.asarray(time_list_BDFextendedODEsize200, dtype=np.float64)
dt_array_BDFextendedODEsize200 = np.asarray(dt_array_BDFextendedODEsize200, dtype=np.float64)
V_array_BDFextendedODEsize200 = np.asarray(V_array_BDFextendedODEsize200, dtype=np.float64)
F_array_BDFextendedODEsize200 = np.asarray(F_array_BDFextendedODEsize200, dtype=np.float64)
rhs_count_array_BDFextendedODEsize200 = np.asarray(rhs_count_array_BDFextendedODEsize200, dtype=np.float64)
ksp_count_array_BDFextendedODEsize200 = np.asarray(ksp_count_array_BDFextendedODEsize200, dtype=np.float64)
max_S_BDFextendedODEsize200 = np.asarray(max_S_BDFextendedODEsize200, dtype=np.float64)
min_S_BDFextendedODEsize200 = np.asarray(min_S_BDFextendedODEsize200, dtype=np.float64)
max_PSI_BDFextendedODEsize200 = np.asarray(max_PSI_BDFextendedODEsize200, dtype=np.float64)
min_PSI_BDFextendedODEsize200 = np.asarray(min_PSI_BDFextendedODEsize200, dtype=np.float64)

time_years_BDFextendedODEsize200 = time_array_BDFextendedODEsize200 / (365.2425*24*3600)

# %%
time_list_BDFextendedODEsize400 = []
dt_array_BDFextendedODEsize400 = []
V_array_BDFextendedODEsize400 = []
F_array_BDFextendedODEsize400 = []
rhs_count_array_BDFextendedODEsize400 = []
ksp_count_array_BDFextendedODEsize400 = []
max_S_BDFextendedODEsize400 = []
min_S_BDFextendedODEsize400 = []
max_PSI_BDFextendedODEsize400 = []
min_PSI_BDFextendedODEsize400 = []
time_old = 0.0



#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size400__AS_extendedode_BDF0_sor-gmres_Vrtol1e-08__EQ_extendedode_BDF0_sor-gmres_Vrtol1e-07.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_BDFextendedODEsize400.append(time)
            dt_array_BDFextendedODEsize400.append(dt)

            V_array_BDFextendedODEsize400.append(row['Vmax'])
            F_array_BDFextendedODEsize400.append(row['fmax'])
            rhs_count_array_BDFextendedODEsize400.append(row['count_rhs'])
            ksp_count_array_BDFextendedODEsize400.append(row['KSP_iteration'])
            max_S_BDFextendedODEsize400.append(row['maxS'])
            min_S_BDFextendedODEsize400.append(row['minS'])
            max_PSI_BDFextendedODEsize400.append(row['maxPSI'])
            min_PSI_BDFextendedODEsize400.append(row['minPSI'])
            
            if (row['t_init']):
                initialization_time_BDFextendedODEsize400 = row['t_init']
            if (row['t_solve']):
                solve_time_BDFextendedODEsize400 = row['t_solve']
            if (row['t_total']):
                total_time_BDFextendedODEsize400 = row['t_total']

time_array_BDFextendedODEsize400 = np.asarray(time_list_BDFextendedODEsize400, dtype=np.float64)
dt_array_BDFextendedODEsize400 = np.asarray(dt_array_BDFextendedODEsize400, dtype=np.float64)
V_array_BDFextendedODEsize400 = np.asarray(V_array_BDFextendedODEsize400, dtype=np.float64)
F_array_BDFextendedODEsize400 = np.asarray(F_array_BDFextendedODEsize400, dtype=np.float64)
rhs_count_array_BDFextendedODEsize400 = np.asarray(rhs_count_array_BDFextendedODEsize400, dtype=np.float64)
ksp_count_array_BDFextendedODEsize400 = np.asarray(ksp_count_array_BDFextendedODEsize400, dtype=np.float64)
max_S_BDFextendedODEsize400 = np.asarray(max_S_BDFextendedODEsize400, dtype=np.float64)
min_S_BDFextendedODEsize400 = np.asarray(min_S_BDFextendedODEsize400, dtype=np.float64)
max_PSI_BDFextendedODEsize400 = np.asarray(max_PSI_BDFextendedODEsize400, dtype=np.float64)
min_PSI_BDFextendedODEsize400 = np.asarray(min_PSI_BDFextendedODEsize400, dtype=np.float64)

time_years_BDFextendedODEsize400 = time_array_BDFextendedODEsize400 / (365.2425*24*3600)

# %%
sizes = np.asarray([52,101, 200, 400], dtype=np.float64)
time_init_compactODE     = np.asarray([initialization_time_compactODEsize52,     initialization_time_compactODEsize101,     initialization_time_compactODEsize200,     initialization_time_compactODEsize400], dtype=np.float64)
time_init_BDFcompactODE  = np.asarray([initialization_time_BDFcompactODEsize52,  initialization_time_BDFcompactODEsize101,  initialization_time_BDFcompactODEsize200,  initialization_time_BDFcompactODEsize400], dtype=np.float64)
time_init_extendedDAE    = np.asarray([initialization_time_extendedDAEsize52,    initialization_time_extendedDAEsize101,    initialization_time_extendedDAEsize200,    initialization_time_extendedDAEsize400], dtype=np.float64)
time_init_extendedODE    = np.asarray([initialization_time_extendedODEsize52,    initialization_time_extendedODEsize101,    initialization_time_extendedODEsize200,    initialization_time_extendedODEsize400], dtype=np.float64)
time_init_BDFextendedODE = np.asarray([initialization_time_BDFextendedODEsize52, initialization_time_BDFextendedODEsize101, initialization_time_BDFextendedODEsize200, initialization_time_BDFextendedODEsize400], dtype=np.float64)

# %%
time_solve_compactODE     = np.asarray([solve_time_compactODEsize52,     solve_time_compactODEsize101,     solve_time_compactODEsize200,     solve_time_compactODEsize400], dtype=np.float64)
time_solve_BDFcompactODE  = np.asarray([solve_time_BDFcompactODEsize52,  solve_time_BDFcompactODEsize101,  solve_time_BDFcompactODEsize200,  solve_time_BDFcompactODEsize400], dtype=np.float64)
time_solve_extendedDAE    = np.asarray([solve_time_extendedDAEsize52,    solve_time_extendedDAEsize101,    solve_time_extendedDAEsize200,    solve_time_extendedDAEsize400], dtype=np.float64)
time_solve_extendedODE    = np.asarray([solve_time_extendedODEsize52,    solve_time_extendedODEsize101,    solve_time_extendedODEsize200,    solve_time_extendedODEsize400], dtype=np.float64)
time_solve_BDFextendedODE = np.asarray([solve_time_BDFextendedODEsize52, solve_time_BDFextendedODEsize101, solve_time_BDFextendedODEsize200, solve_time_BDFextendedODEsize400], dtype=np.float64)

# %%
time_total_compactODE     = np.asarray([total_time_compactODEsize52,     total_time_compactODEsize101,     total_time_compactODEsize200,     total_time_compactODEsize400], dtype=np.float64)
time_total_BDFcompactODE  = np.asarray([total_time_BDFcompactODEsize52,  total_time_BDFcompactODEsize101,  total_time_BDFcompactODEsize200,  total_time_BDFcompactODEsize400], dtype=np.float64)
time_total_extendedDAE    = np.asarray([total_time_extendedDAEsize52,    total_time_extendedDAEsize101,    total_time_extendedDAEsize200,    total_time_extendedDAEsize400], dtype=np.float64)
time_total_extendedODE    = np.asarray([total_time_extendedODEsize52,    total_time_extendedODEsize101,    total_time_extendedODEsize200,    total_time_extendedODEsize400], dtype=np.float64)
time_total_BDFextendedODE = np.asarray([total_time_BDFextendedODEsize52, total_time_BDFextendedODEsize101, total_time_BDFextendedODEsize200, total_time_BDFextendedODEsize400], dtype=np.float64)

# %%
number_timesteps_compactODE     = np.asarray([np.size(time_array_compactODEsize52),     np.size(time_array_compactODEsize101),     np.size(time_array_compactODEsize200),     np.size(time_array_compactODEsize400)], dtype=np.float64)
number_timesteps_BDFcompactODE  = np.asarray([np.size(time_array_BDFcompactODEsize52),  np.size(time_array_BDFcompactODEsize101),  np.size(time_array_BDFcompactODEsize200),  np.size(time_array_BDFcompactODEsize400)], dtype=np.float64)
number_timesteps_extendedDAE    = np.asarray([np.size(time_array_extendedDAEsize52),    np.size(time_array_extendedDAEsize101),    np.size(time_array_extendedDAEsize200),    np.size(time_array_extendedDAEsize400)], dtype=np.float64)
number_timesteps_extendedODE    = np.asarray([np.size(time_array_extendedODEsize52),    np.size(time_array_extendedODEsize101),    np.size(time_array_extendedODEsize200),    np.size(time_array_extendedODEsize400)], dtype=np.float64)
number_timesteps_BDFextendedODE = np.asarray([np.size(time_array_BDFextendedODEsize52), np.size(time_array_BDFextendedODEsize101), np.size(time_array_BDFextendedODEsize200), np.size(time_array_BDFextendedODEsize400)], dtype=np.float64)

# %%
number_RHS_evaluations_compactODE     = np.asarray([np.sum(rhs_count_array_compactODEsize52),     np.sum(rhs_count_array_compactODEsize101),     np.sum(rhs_count_array_compactODEsize200),     np.sum(rhs_count_array_compactODEsize400)], dtype=np.float64)
number_RHS_evaluations_BDFcompactODE  = np.asarray([np.sum(rhs_count_array_BDFcompactODEsize52),  np.sum(rhs_count_array_BDFcompactODEsize101),  np.sum(rhs_count_array_BDFcompactODEsize200),  np.sum(rhs_count_array_BDFcompactODEsize400)], dtype=np.float64)
number_RHS_evaluations_extendedDAE    = np.asarray([np.sum(rhs_count_array_extendedDAEsize52),    np.sum(rhs_count_array_extendedDAEsize101),    np.sum(rhs_count_array_extendedDAEsize200),    np.sum(rhs_count_array_extendedDAEsize400)], dtype=np.float64)
number_RHS_evaluations_extendedODE    = np.asarray([np.sum(rhs_count_array_extendedODEsize52),    np.sum(rhs_count_array_extendedODEsize101),    np.sum(rhs_count_array_extendedODEsize200),    np.sum(rhs_count_array_extendedODEsize400)], dtype=np.float64)
number_RHS_evaluations_BDFextendedODE = np.asarray([np.sum(rhs_count_array_BDFextendedODEsize52), np.sum(rhs_count_array_BDFextendedODEsize101), np.sum(rhs_count_array_BDFextendedODEsize200), np.sum(rhs_count_array_BDFextendedODEsize400)], dtype=np.float64)

# %%
average_number_ksp_evaluations_BDFcompactODE  = np.asarray([np.average(ksp_count_array_BDFcompactODEsize52),  np.average(ksp_count_array_BDFcompactODEsize101),  np.average(ksp_count_array_BDFcompactODEsize200),  np.average(ksp_count_array_BDFcompactODEsize400)], dtype=np.float64)
average_number_ksp_evaluations_extendedDAE    = np.asarray([np.average(ksp_count_array_extendedDAEsize52),    np.average(ksp_count_array_extendedDAEsize101),    np.average(ksp_count_array_extendedDAEsize200),    np.average(ksp_count_array_extendedDAEsize400)], dtype=np.float64)
average_number_ksp_evaluations_BDFextendedODE = np.asarray([np.average(ksp_count_array_BDFextendedODEsize52), np.average(ksp_count_array_BDFextendedODEsize101), np.average(ksp_count_array_BDFextendedODEsize200), np.average(ksp_count_array_BDFextendedODEsize400)], dtype=np.float64)

# %%
average_number_rhs_evaluations_BDFcompactODE  = np.asarray([np.average(rhs_count_array_BDFcompactODEsize52),  np.average(rhs_count_array_BDFcompactODEsize101),  np.average(rhs_count_array_BDFcompactODEsize200),  np.average(rhs_count_array_BDFcompactODEsize400)], dtype=np.float64)
average_number_rhs_evaluations_extendedDAE    = np.asarray([np.average(rhs_count_array_extendedDAEsize52),    np.average(rhs_count_array_extendedDAEsize101),    np.average(rhs_count_array_extendedDAEsize200),    np.average(rhs_count_array_extendedDAEsize400)], dtype=np.float64)
average_number_rhs_evaluations_BDFextendedODE = np.asarray([np.average(rhs_count_array_BDFextendedODEsize52), np.average(rhs_count_array_BDFextendedODEsize101), np.average(rhs_count_array_BDFextendedODEsize200), np.average(rhs_count_array_BDFextendedODEsize400)], dtype=np.float64)

# %%
average_number_Newton_steps_BDFcompactODE  = average_number_rhs_evaluations_BDFcompactODE  - 1
average_number_Newton_steps_extendedDAE    = average_number_rhs_evaluations_extendedDAE    - 1
average_number_Newton_steps_BDFextendedODE = average_number_rhs_evaluations_BDFextendedODE - 1

# %%
V0 = 1e-6
dt_AS_BDFextendedODEsize52  = dt_array_BDFextendedODEsize52[ V_array_BDFextendedODEsize52  < V0]
dt_AS_BDFextendedODEsize101 = dt_array_BDFextendedODEsize101[V_array_BDFextendedODEsize101 < V0]
dt_AS_BDFextendedODEsize200 = dt_array_BDFextendedODEsize200[V_array_BDFextendedODEsize200 < V0]
dt_AS_BDFextendedODEsize400 = dt_array_BDFextendedODEsize400[V_array_BDFextendedODEsize400 < V0]

mean_dt_AS_BDFextendedODEsize52  = np.exp(np.average(np.log(dt_AS_BDFextendedODEsize52)))
mean_dt_AS_BDFextendedODEsize101 = np.exp(np.average(np.log(dt_AS_BDFextendedODEsize101)))
mean_dt_AS_BDFextendedODEsize200 = np.exp(np.average(np.log(dt_AS_BDFextendedODEsize200)))
mean_dt_AS_BDFextendedODEsize400 = np.exp(np.average(np.log(dt_AS_BDFextendedODEsize400)))

mean_dt_AS_BDFextendedODE = np.asarray([mean_dt_AS_BDFextendedODEsize52,  mean_dt_AS_BDFextendedODEsize101, 
                                        mean_dt_AS_BDFextendedODEsize200, mean_dt_AS_BDFextendedODEsize400], dtype=np.float64) 

dt_EQ_BDFextendedODEsize52  = dt_array_BDFextendedODEsize52[ V_array_BDFextendedODEsize52  > V0]
dt_EQ_BDFextendedODEsize101 = dt_array_BDFextendedODEsize101[V_array_BDFextendedODEsize101 > V0]
dt_EQ_BDFextendedODEsize200 = dt_array_BDFextendedODEsize200[V_array_BDFextendedODEsize200 > V0]
dt_EQ_BDFextendedODEsize400 = dt_array_BDFextendedODEsize400[V_array_BDFextendedODEsize400 > V0]

mean_dt_EQ_BDFextendedODEsize52  = np.exp(np.average(np.log(dt_EQ_BDFextendedODEsize52)))
mean_dt_EQ_BDFextendedODEsize101 = np.exp(np.average(np.log(dt_EQ_BDFextendedODEsize101)))
mean_dt_EQ_BDFextendedODEsize200 = np.exp(np.average(np.log(dt_EQ_BDFextendedODEsize200)))
mean_dt_EQ_BDFextendedODEsize400 = np.exp(np.average(np.log(dt_EQ_BDFextendedODEsize400)))

mean_dt_EQ_BDFextendedODE = np.asarray([mean_dt_EQ_BDFextendedODEsize52,  mean_dt_EQ_BDFextendedODEsize101, 
                                        mean_dt_EQ_BDFextendedODEsize200, mean_dt_EQ_BDFextendedODEsize400], dtype=np.float64)

# %%
V0 = 1e-6
dt_AS_extendedODEsize52  = dt_array_extendedODEsize52[ V_array_extendedODEsize52  < V0]
dt_AS_extendedODEsize101 = dt_array_extendedODEsize101[V_array_extendedODEsize101 < V0]
dt_AS_extendedODEsize200 = dt_array_extendedODEsize200[V_array_extendedODEsize200 < V0]
dt_AS_extendedODEsize400 = dt_array_extendedODEsize400[V_array_extendedODEsize400 < V0]

mean_dt_AS_extendedODEsize52  = np.exp(np.average(np.log(dt_AS_extendedODEsize52)))
mean_dt_AS_extendedODEsize101 = np.exp(np.average(np.log(dt_AS_extendedODEsize101)))
mean_dt_AS_extendedODEsize200 = np.exp(np.average(np.log(dt_AS_extendedODEsize200)))
mean_dt_AS_extendedODEsize400 = np.exp(np.average(np.log(dt_AS_extendedODEsize400)))

mean_dt_AS_extendedODE = np.asarray([mean_dt_AS_extendedODEsize52,  mean_dt_AS_extendedODEsize101, 
                                     mean_dt_AS_extendedODEsize200, mean_dt_AS_extendedODEsize400], dtype=np.float64) 

dt_EQ_extendedODEsize52  = dt_array_extendedODEsize52[ V_array_extendedODEsize52  > V0]
dt_EQ_extendedODEsize101 = dt_array_extendedODEsize101[V_array_extendedODEsize101 > V0]
dt_EQ_extendedODEsize200 = dt_array_extendedODEsize200[V_array_extendedODEsize200 > V0]
dt_EQ_extendedODEsize400 = dt_array_extendedODEsize400[V_array_extendedODEsize400 > V0]

mean_dt_EQ_extendedODEsize52  = np.exp(np.average(np.log(dt_EQ_extendedODEsize52)))
mean_dt_EQ_extendedODEsize101 = np.exp(np.average(np.log(dt_EQ_extendedODEsize101)))
mean_dt_EQ_extendedODEsize200 = np.exp(np.average(np.log(dt_EQ_extendedODEsize200)))
mean_dt_EQ_extendedODEsize400 = np.exp(np.average(np.log(dt_EQ_extendedODEsize400)))

mean_dt_EQ_extendedODE = np.asarray([mean_dt_EQ_extendedODEsize52,  mean_dt_EQ_extendedODEsize101, 
                                     mean_dt_EQ_extendedODEsize200, mean_dt_EQ_extendedODEsize400], dtype=np.float64)

# %%
V0 = 1e-6
dt_AS_extendedDAEsize52  = dt_array_extendedDAEsize52[ V_array_extendedDAEsize52  < V0]
dt_AS_extendedDAEsize101 = dt_array_extendedDAEsize101[V_array_extendedDAEsize101 < V0]
dt_AS_extendedDAEsize200 = dt_array_extendedDAEsize200[V_array_extendedDAEsize200 < V0]
dt_AS_extendedDAEsize400 = dt_array_extendedDAEsize400[V_array_extendedDAEsize400 < V0]

mean_dt_AS_extendedDAEsize52  = np.exp(np.average(np.log(dt_AS_extendedDAEsize52)))
mean_dt_AS_extendedDAEsize101 = np.exp(np.average(np.log(dt_AS_extendedDAEsize101)))
mean_dt_AS_extendedDAEsize200 = np.exp(np.average(np.log(dt_AS_extendedDAEsize200)))
mean_dt_AS_extendedDAEsize400 = np.exp(np.average(np.log(dt_AS_extendedDAEsize400)))

mean_dt_AS_extendedDAE = np.asarray([mean_dt_AS_extendedDAEsize52,  mean_dt_AS_extendedDAEsize101, 
                                     mean_dt_AS_extendedDAEsize200, mean_dt_AS_extendedDAEsize400], dtype=np.float64) 

dt_EQ_extendedDAEsize52  = dt_array_extendedDAEsize52[ V_array_extendedDAEsize52  > V0]
dt_EQ_extendedDAEsize101 = dt_array_extendedDAEsize101[V_array_extendedDAEsize101 > V0]
dt_EQ_extendedDAEsize200 = dt_array_extendedDAEsize200[V_array_extendedDAEsize200 > V0]
dt_EQ_extendedDAEsize400 = dt_array_extendedDAEsize400[V_array_extendedDAEsize400 > V0]

mean_dt_EQ_extendedDAEsize52  = np.exp(np.average(np.log(dt_EQ_extendedDAEsize52)))
mean_dt_EQ_extendedDAEsize101 = np.exp(np.average(np.log(dt_EQ_extendedDAEsize101)))
mean_dt_EQ_extendedDAEsize200 = np.exp(np.average(np.log(dt_EQ_extendedDAEsize200)))
mean_dt_EQ_extendedDAEsize400 = np.exp(np.average(np.log(dt_EQ_extendedDAEsize400)))

mean_dt_EQ_extendedDAE = np.asarray([mean_dt_EQ_extendedDAEsize52,  mean_dt_EQ_extendedDAEsize101, 
                                     mean_dt_EQ_extendedDAEsize200, mean_dt_EQ_extendedDAEsize400], dtype=np.float64)

# %%
V0 = 1e-6
dt_AS_BDFcompactODEsize52  = dt_array_BDFcompactODEsize52[ V_array_BDFcompactODEsize52  < V0]
dt_AS_BDFcompactODEsize101 = dt_array_BDFcompactODEsize101[V_array_BDFcompactODEsize101 < V0]
dt_AS_BDFcompactODEsize200 = dt_array_BDFcompactODEsize200[V_array_BDFcompactODEsize200 < V0]
dt_AS_BDFcompactODEsize400 = dt_array_BDFcompactODEsize400[V_array_BDFcompactODEsize400 < V0]

mean_dt_AS_BDFcompactODEsize52  = np.exp(np.average(np.log(dt_AS_BDFcompactODEsize52)))
mean_dt_AS_BDFcompactODEsize101 = np.exp(np.average(np.log(dt_AS_BDFcompactODEsize101)))
mean_dt_AS_BDFcompactODEsize200 = np.exp(np.average(np.log(dt_AS_BDFcompactODEsize200)))
mean_dt_AS_BDFcompactODEsize400 = np.exp(np.average(np.log(dt_AS_BDFcompactODEsize400)))

mean_dt_AS_BDFcompactODE = np.asarray([mean_dt_AS_BDFcompactODEsize52,  mean_dt_AS_BDFcompactODEsize101, 
                                       mean_dt_AS_BDFcompactODEsize200, mean_dt_AS_BDFcompactODEsize400], dtype=np.float64) 

dt_EQ_BDFcompactODEsize52  = dt_array_BDFcompactODEsize52[ V_array_BDFcompactODEsize52  > V0]
dt_EQ_BDFcompactODEsize101 = dt_array_BDFcompactODEsize101[V_array_BDFcompactODEsize101 > V0]
dt_EQ_BDFcompactODEsize200 = dt_array_BDFcompactODEsize200[V_array_BDFcompactODEsize200 > V0]
dt_EQ_BDFcompactODEsize400 = dt_array_BDFcompactODEsize400[V_array_BDFcompactODEsize400 > V0]

mean_dt_EQ_BDFcompactODEsize52  = np.exp(np.average(np.log(dt_EQ_BDFcompactODEsize52)))
mean_dt_EQ_BDFcompactODEsize101 = np.exp(np.average(np.log(dt_EQ_BDFcompactODEsize101)))
mean_dt_EQ_BDFcompactODEsize200 = np.exp(np.average(np.log(dt_EQ_BDFcompactODEsize200)))
mean_dt_EQ_BDFcompactODEsize400 = np.exp(np.average(np.log(dt_EQ_BDFcompactODEsize400)))

mean_dt_EQ_BDFcompactODE = np.asarray([mean_dt_EQ_BDFcompactODEsize52,  mean_dt_EQ_BDFcompactODEsize101, 
                                       mean_dt_EQ_BDFcompactODEsize200, mean_dt_EQ_BDFcompactODEsize400], dtype=np.float64)

# %%
V0 = 1e-6
dt_AS_compactODEsize52  = dt_array_compactODEsize52[ V_array_compactODEsize52  < V0]
dt_AS_compactODEsize101 = dt_array_compactODEsize101[V_array_compactODEsize101 < V0]
dt_AS_compactODEsize200 = dt_array_compactODEsize200[V_array_compactODEsize200 < V0]
dt_AS_compactODEsize400 = dt_array_compactODEsize400[V_array_compactODEsize400 < V0]

mean_dt_AS_compactODEsize52  = np.exp(np.average(np.log(dt_AS_compactODEsize52)))
mean_dt_AS_compactODEsize101 = np.exp(np.average(np.log(dt_AS_compactODEsize101)))
mean_dt_AS_compactODEsize200 = np.exp(np.average(np.log(dt_AS_compactODEsize200)))
mean_dt_AS_compactODEsize400 = np.exp(np.average(np.log(dt_AS_compactODEsize400)))

mean_dt_AS_compactODE = np.asarray([mean_dt_AS_compactODEsize52,  mean_dt_AS_compactODEsize101, 
                                    mean_dt_AS_compactODEsize200, mean_dt_AS_compactODEsize400], dtype=np.float64) 

dt_EQ_compactODEsize52  = dt_array_compactODEsize52[ V_array_compactODEsize52  > V0]
dt_EQ_compactODEsize101 = dt_array_compactODEsize101[V_array_compactODEsize101 > V0]
dt_EQ_compactODEsize200 = dt_array_compactODEsize200[V_array_compactODEsize200 > V0]
dt_EQ_compactODEsize400 = dt_array_compactODEsize400[V_array_compactODEsize400 > V0]

mean_dt_EQ_compactODEsize52  = np.exp(np.average(np.log(dt_EQ_compactODEsize52)))
mean_dt_EQ_compactODEsize101 = np.exp(np.average(np.log(dt_EQ_compactODEsize101)))
mean_dt_EQ_compactODEsize200 = np.exp(np.average(np.log(dt_EQ_compactODEsize200)))
mean_dt_EQ_compactODEsize400 = np.exp(np.average(np.log(dt_EQ_compactODEsize400)))

mean_dt_EQ_compactODE = np.asarray([mean_dt_EQ_compactODEsize52,  mean_dt_EQ_compactODEsize101, 
                                    mean_dt_EQ_compactODEsize200, mean_dt_EQ_compactODEsize400], dtype=np.float64)

# %%
mean_F_BDFcompactODEsize52  = np.exp(np.average(np.log(F_array_BDFcompactODEsize52)))
mean_F_BDFcompactODEsize101 = np.exp(np.average(np.log(F_array_BDFcompactODEsize101)))
mean_F_BDFcompactODEsize200 = np.exp(np.average(np.log(F_array_BDFcompactODEsize200)))
mean_F_BDFcompactODEsize400 = np.exp(np.average(np.log(F_array_BDFcompactODEsize400)))

mean_F_BDFcompactODE = np.asarray([mean_F_BDFcompactODEsize52,  mean_F_BDFcompactODEsize101, 
                                   mean_F_BDFcompactODEsize200, mean_F_BDFcompactODEsize400], dtype=np.float64)

# %%
mean_F_extendedDAEsize52  = np.exp(np.average(np.log(F_array_extendedDAEsize52)))
mean_F_extendedDAEsize101 = np.exp(np.average(np.log(F_array_extendedDAEsize101)))
mean_F_extendedDAEsize200 = np.exp(np.average(np.log(F_array_extendedDAEsize200)))
mean_F_extendedDAEsize400 = np.exp(np.average(np.log(F_array_extendedDAEsize400)))

mean_F_extendedDAE = np.asarray([mean_F_extendedDAEsize52,  mean_F_extendedDAEsize101, 
                                   mean_F_extendedDAEsize200, mean_F_extendedDAEsize400], dtype=np.float64)

# %%
mean_F_BDFextendedODEsize52  = np.exp(np.average(np.log(F_array_BDFextendedODEsize52)))
mean_F_BDFextendedODEsize101 = np.exp(np.average(np.log(F_array_BDFextendedODEsize101)))
mean_F_BDFextendedODEsize200 = np.exp(np.average(np.log(F_array_BDFextendedODEsize200)))
mean_F_BDFextendedODEsize400 = np.exp(np.average(np.log(F_array_BDFextendedODEsize400)))

mean_F_BDFextendedODE = np.asarray([mean_F_BDFextendedODEsize52,  mean_F_BDFextendedODEsize101, 
                                   mean_F_BDFextendedODEsize200, mean_F_BDFextendedODEsize400], dtype=np.float64)

# %%
time_per_step_compactODE     = time_solve_compactODE     / number_timesteps_compactODE
time_per_step_BDFcompactODE  = time_solve_BDFcompactODE  / number_timesteps_BDFcompactODE
time_per_step_extendedDAE    = time_solve_extendedDAE    / number_timesteps_extendedDAE
time_per_step_extendedODE    = time_solve_extendedODE    / number_timesteps_extendedODE
time_per_step_BDFextendedODE = time_solve_BDFextendedODE / number_timesteps_BDFextendedODE

# %%
time_per_rhs_evaluation_compactODE     = time_solve_compactODE     / number_RHS_evaluations_compactODE
time_per_rhs_evaluation_BDFcompactODE  = time_solve_BDFcompactODE  / number_RHS_evaluations_BDFcompactODE
time_per_rhs_evaluation_extendedDAE    = time_solve_extendedDAE    / number_RHS_evaluations_extendedDAE
time_per_rhs_evaluation_extendedODE    = time_solve_extendedODE    / number_RHS_evaluations_extendedODE
time_per_rhs_evaluation_BDFextendedODE = time_solve_BDFextendedODE / number_RHS_evaluations_BDFextendedODE

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(sizes, average_number_Newton_steps_BDFcompactODE, '--sr', mfc='none', label ='1st order ODE (BDF)')
plt.plot(sizes, average_number_Newton_steps_extendedDAE,   '--ob', mfc='none', label ='extended DAE (BDF)' )
plt.plot(sizes, average_number_Newton_steps_BDFextendedODE,'--dg', mfc='none', label ='2nd order ODE (BDF)')

plt.xlabel("problem size")
plt.ylabel("mean Newton steps")

plt.xscale('log')
#plt.yscale('log')

ax = plt.gca()

ax.set_xticks([52, 101, 200, 400])
ax.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:.0f}'))
ax.xaxis.set_minor_formatter(mticker.NullFormatter())
ax.xaxis.set_major_formatter(mticker.ScalarFormatter())
#plt.legend(bbox_to_anchor=(-0.2, 0.7))

plt.savefig('../results/TANDEM_averageNumberNewtonSteps.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(sizes, average_number_ksp_evaluations_BDFcompactODE, '--sr', mfc='none', label ='1st order ODE (BDF)')
plt.plot(sizes, average_number_ksp_evaluations_BDFextendedODE,'--og', mfc='none', label ='2nd order ODE (BDF)')
plt.plot(sizes, average_number_ksp_evaluations_extendedDAE,   '--db', mfc='none', label ='extended DAE (BDF)' )

plt.xlabel("problem size")
plt.ylabel("mean GMRES iterations")

plt.xscale('log')
#plt.yscale('log')

ax = plt.gca()

ax.set_xticks([52, 101, 200, 400])
ax.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:.0f}'))
ax.xaxis.set_minor_formatter(mticker.NullFormatter())
ax.xaxis.set_major_formatter(mticker.ScalarFormatter())
plt.legend(bbox_to_anchor=(0.5, +1.05), loc='lower center')

plt.savefig('../results/TANDEM_averageNumberKSPIteration.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(sizes, mean_F_BDFcompactODE, '--sr', mfc='none', label ='1st order ODE (BDF)')
plt.plot(sizes, mean_F_BDFextendedODE,'--og', mfc='none', label ='2nd order ODE (BDF)')
plt.plot(sizes, mean_F_extendedDAE,   '--db', mfc='none', label ='extended DAE (BDF)' )

plt.xlabel("problem size")
plt.ylabel("mean maximum residual")

plt.xscale('log')
plt.yscale('log')

ax = plt.gca()

ax.set_xticks([52, 101, 200, 400])
ax.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:.0f}'))
ax.xaxis.set_minor_formatter(mticker.NullFormatter())
ax.xaxis.set_major_formatter(mticker.ScalarFormatter())
#plt.legend()

plt.savefig('../results/TANDEM_maximumResidualNorm.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(sizes, mean_dt_AS_BDFcompactODE, '--xr', label ='1st order ODE (BDF)')
plt.plot(sizes, mean_dt_AS_BDFextendedODE,'--xg', label ='2nd order ODE (BDF)')
plt.plot(sizes, mean_dt_AS_extendedDAE,   '--xb', label ='extended DAE (BDF)' )
plt.plot(sizes, mean_dt_AS_compactODE,    '-xr', label ='1st order ODE (RK)' )
plt.plot(sizes, mean_dt_AS_extendedODE,   '-xg', label ='2nd order ODE (RK)' )

plt.xlabel("problem size")
plt.ylabel("Mean timestep size [s]")

plt.xscale('log')
plt.yscale('log')

#plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))

ax = plt.gca()

ax.set_xticks([52, 101, 200, 400])
ax.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:.0f}'))
ax.xaxis.set_minor_formatter(mticker.NullFormatter())
ax.xaxis.set_major_formatter(mticker.ScalarFormatter())
                     

plt.savefig('../results/TANDEM_MeanTimeStepSize_AseismicPhase.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(sizes, mean_dt_EQ_BDFcompactODE, '--xr', label ='1st order ODE (BDF)')
plt.plot(sizes, mean_dt_EQ_BDFextendedODE,'--xg', label ='2nd order ODE (BDF)')
plt.plot(sizes, mean_dt_EQ_extendedDAE,   '--xb', label ='extended DAE (BDF)' )
plt.plot(sizes, mean_dt_EQ_compactODE,    '-xr',  label ='1st order ODE (RK)' )
plt.plot(sizes, mean_dt_EQ_extendedODE,   '-xg',  label ='2nd order ODE (RK)' )

plt.xlabel("problem size")
plt.ylabel("Mean timestep size [s]")

plt.xscale('log')
plt.yscale('log')

ax = plt.gca()

ax.set_xticks([52, 101, 200, 400])
ax.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:.0f}'))
ax.xaxis.set_minor_formatter(mticker.NullFormatter())
ax.xaxis.set_major_formatter(mticker.ScalarFormatter())
                     
plt.legend(bbox_to_anchor=(0.5, +1.05), loc='lower center',ncol=2)

plt.savefig('../results/TANDEM_MeanTimeStepSize_EarthquakePhase.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(sizes, number_timesteps_BDFcompactODE, '--sr', mfc='none', label ='1st order ODE (BDF)')
plt.plot(sizes, number_timesteps_BDFextendedODE,'--og', mfc='none', label ='2nd order ODE (BDF)')
plt.plot(sizes, number_timesteps_extendedDAE,   '--db', mfc='none', label ='extended DAE (BDF)' )
plt.plot(sizes, number_timesteps_compactODE,    '-sr', label ='1st order ODE (RK)' )
plt.plot(sizes, number_timesteps_extendedODE,   '-og', label ='2nd order ODE (RK)' )

plt.xlabel("problem size")
plt.ylabel("Total number of timesteps")

plt.xscale('log')
#plt.yscale('log')

ax = plt.gca()

ax.set_xticks([52, 101, 200, 400])
ax.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:.0f}'))
ax.xaxis.set_minor_formatter(mticker.NullFormatter())
ax.xaxis.set_major_formatter(mticker.ScalarFormatter())

plt.legend(bbox_to_anchor=(0.5, +1.05), loc='lower center',ncol=2)

plt.savefig('../results/TANDEM_NumberTimeSteps_differentSizes.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(sizes, time_per_rhs_evaluation_BDFcompactODE, '--sr', mfc='none', label ='1st order ODE (BDF)')
plt.plot(sizes, time_per_rhs_evaluation_BDFextendedODE,'--og', mfc='none', label ='2nd order ODE (BDF)')
plt.plot(sizes, time_per_rhs_evaluation_extendedDAE,   '--db', mfc='none', label ='extended DAE (BDF)' )
plt.plot(sizes, time_per_rhs_evaluation_compactODE,    '-sr', label ='1st order ODE (RK)' )
plt.plot(sizes, time_per_rhs_evaluation_extendedODE,   '-og', label ='2nd order ODE (RK)' )

plt.xlabel("problem size")
plt.ylabel("CPU time [s]")

plt.xscale('log')
plt.yscale('log')

ax = plt.gca()

ax.set_xticks([52, 101, 200, 400])
ax.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:.0f}'))
ax.xaxis.set_minor_formatter(mticker.NullFormatter())
ax.xaxis.set_major_formatter(mticker.ScalarFormatter())

#plt.legend()

plt.savefig('../results/TANDEM_TimePerRHSEvaluation_differentSizes.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(sizes, time_init_BDFcompactODE, '--sr', mfc='none', label ='1st order ODE (BDF)')
plt.plot(sizes, time_init_BDFextendedODE,'--og', mfc='none', label ='2nd order ODE (BDF)')
plt.plot(sizes, time_init_extendedDAE,   '--db', mfc='none', label ='extended DAE (BDF)' )
plt.plot(sizes, time_init_compactODE,    '-sr',  label ='1st order ODE (RK)' )
plt.plot(sizes, time_init_extendedODE,   '-og',  label ='2nd order ODE (RK)' )

plt.xlabel("problem size")
plt.ylabel("CPU time [s]")

plt.xscale('log')
plt.yscale('log')

ax = plt.gca()

ax.set_xticks([52, 101, 200, 400])
ax.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:.0f}'))
ax.xaxis.set_minor_formatter(mticker.NullFormatter())
ax.xaxis.set_major_formatter(mticker.ScalarFormatter())
plt.legend(bbox_to_anchor=(0.5, +1.05), loc='lower center',ncol=2)

plt.savefig('../results/TANDEM_CPU_Time_intialization.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(sizes, time_solve_BDFcompactODE, '--sr', mfc='none', label ='1st order ODE (BDF)')
plt.plot(sizes, time_solve_BDFextendedODE,'--og', mfc='none', label ='2nd order ODE (BDF)')
plt.plot(sizes, time_solve_extendedDAE,   '--db', mfc='none', label ='extended DAE (BDF)' )
plt.plot(sizes, time_solve_compactODE,    '-sr', label ='1st order ODE (RK)' )
plt.plot(sizes, time_solve_extendedODE,   '-og', label ='2nd order ODE (RK)' )

plt.xlabel("problem size")
plt.ylabel("CPU time [s]")

plt.xscale('log')
plt.yscale('log')

ax = plt.gca()

ax.set_xticks([52, 101, 200, 400])
ax.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:.0f}'))
ax.xaxis.set_minor_formatter(mticker.NullFormatter())
ax.xaxis.set_major_formatter(mticker.ScalarFormatter())

#plt.legend()

plt.savefig('../results/TANDEM_CPU_Time_solving.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(dt_array_compactODEsize400,Color='black',      label ='400')
plt.plot(dt_array_compactODEsize200,Color='red',        label ='200')
plt.plot(dt_array_compactODEsize101,Color='darkorange', label ='101')
#plt.plot(dt_array_compactODEsize52,Color='gold',        label ='52' )

plt.xlabel("timestep number")
plt.ylabel("Timestep size [s]")

plt.yscale('log')
plt.ylim([1e-4, 1e8])

plt.savefig('../results/TANDEM_DT_differentSizes_compactODE.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(dt_array_BDFcompactODEsize400,Color='black',      label =r'$n=400$')
plt.plot(dt_array_BDFcompactODEsize200,Color='red',        label =r'$n=200$')
plt.plot(dt_array_BDFcompactODEsize101,Color='darkorange', label =r'$n=101$')
#plt.plot(dt_array_BDFcompactODEsize52,Color='gold',        label ='52' )

plt.xlabel("timestep number")
plt.ylabel("Timestep size [s]")

plt.yscale('log')
plt.ylim([1e-4, 1e8])

plt.savefig('../results/TANDEM_DT_differentSizes_BDFcompactODE.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(dt_array_extendedDAEsize400,Color='black',      label =r'$n=400$')
plt.plot(dt_array_extendedDAEsize200,Color='red',        label =r'$n=200$')
plt.plot(dt_array_extendedDAEsize101,Color='darkorange', label =r'$n=101$')
#plt.plot(dt_array_extendedDAEsize52,Color='gold',        label ='52' )

plt.xlabel("timestep number")
plt.ylabel("Timestep size [s]")

plt.yscale('log')
plt.ylim([1e-4, 1e8])

plt.savefig('../results/TANDEM_DT_differentSizes_extendedDAE.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(dt_array_extendedODEsize400,Color='black',      label =r'$n=400$')
plt.plot(dt_array_extendedODEsize200,Color='red',        label =r'$n=200$')
plt.plot(dt_array_extendedODEsize101,Color='darkorange', label =r'$n=101$')
#plt.plot(dt_array_extendedODEsize52,Color='gold',        label ='52' )

plt.xlabel("timestep number")
plt.ylabel("Timestep size [s]")

plt.yscale('log')
plt.ylim([1e-4, 1e8])

#plt.legend(bbox_to_anchor=(0.5, +1.05), loc='lower center',ncol=3)

plt.savefig('../results/TANDEM_DT_differentSizes_extendedODE.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 27})
params = {'text.latex.preamble' : [r'\usepackage{siunitx}', r'\usepackage{amsmath}']}
plt.rcParams.update(params)

plt.plot(dt_array_BDFextendedODEsize400,Color='black',      label =r'$n=400$')
plt.plot(dt_array_BDFextendedODEsize200,Color='red',        label =r'$n=200$')
plt.plot(dt_array_BDFextendedODEsize101,Color='darkorange', label =r'$n=101$')
#plt.plot(dt_array_BDFextendedODEsize52,Color='gold',        label ='52' )

plt.xlabel("timestep number")
plt.ylabel("Timestep size [s]")

plt.yscale('log')
plt.ylim([1e-4, 1e8])

plt.legend(bbox_to_anchor=(0.5, +1.05), loc='lower center',ncol=3)

plt.savefig('../results/TANDEM_DT_differentSizes_BDFextendedODE.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
average_1st_order = (time_per_rhs_evaluation_compactODE + time_per_rhs_evaluation_BDFcompactODE + time_per_rhs_evaluation_extendedDAE) / 3

print(time_init_compactODE    / time_solve_compactODE)
print(time_init_BDFcompactODE / time_solve_BDFcompactODE)
print(time_init_extendedDAE   / time_solve_extendedDAE)
print(time_init_extendedODE   / time_solve_extendedODE)
# Out:
# [0.000464   0.00039    0.00028909 0.00040546]
# [0.00259449 0.00399699 0.00391765 0.00917997]
# [0.00304929 0.00344809 0.00595858 0.01128245]
# [0.05711393 0.04102477 0.04973396 0.07039076]

# %%
print('                       n=52      n=101       n=200       n=400')
print('compact ODE (BDF)  ', time_total_BDFcompactODE / time_total_compactODE)
print('extended DAE (BDF) ', time_total_extendedDAE / time_total_compactODE)
print('extended ODE (BDF) ', time_total_BDFextendedODE / time_total_compactODE)
print('extended ODE (RK)  ', time_total_extendedODE / time_total_compactODE)
# Out:
#                        n=52      n=101       n=200       n=400
# compact ODE (BDF)   [0.94094328 1.14570184 1.23211162 1.42985144]
# extended DAE (BDF)  [0.80710318 0.88995288 0.68010047 0.54600438]
# extended ODE (BDF)  [0.28384363 1.21894216 1.32872173 2.62314953]
# extended ODE (RK)   [0.04243853 0.10658205 0.09235878 0.10211999]
