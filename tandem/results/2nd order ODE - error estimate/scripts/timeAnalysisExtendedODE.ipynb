# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cbook as cbook
import csv
import pylab
from scipy.interpolate import interp1d


np.set_printoptions(threshold=sys.maxsize)

begin_surroundings = 198
end_surroundings = 199

begin_earthquake = 6259313254
end_earthquake =   6259316754

# %%
time_list_ext_rtol5 = []
dt_array_ext_rtol5 = []
V_array_ext_rtol5 = []
f_array_ext_rtol5 = []
rhs_count_array_ext_rtol5 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../../../build/TANDEM_size101__AS_extendedode_5dp_Vrtol1e-05__EQ_extendedode_5dp_Vrtol1e-05.csv', newline='') as csvfile:
#with open('../results/TANDEM_size101__AS_extendedode_5dp_Vrtol1e-05__EQ_extendedode_5dp_Vrtol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_rtol5.append(time)
            dt_array_ext_rtol5.append(dt)

            V_array_ext_rtol5.append(row['Vmax'])
            f_array_ext_rtol5.append(row['fmax'])
            rhs_count_array_ext_rtol5.append(row['count_rhs'])

time_array_ext_rtol5 = np.asarray(time_list_ext_rtol5, dtype=np.float64)
dt_array_ext_rtol5 = np.asarray(dt_array_ext_rtol5, dtype=np.float64)
V_array_ext_rtol5 = np.asarray(V_array_ext_rtol5, dtype=np.float64)
f_array_ext_rtol5 = np.asarray(f_array_ext_rtol5, dtype=np.float64)
rhs_count_array_ext_rtol5 = np.asarray(rhs_count_array_ext_rtol5, dtype=np.float64)

time_years_ext_rtol5 = time_array_ext_rtol5 / (365.2425*24*3600)

# %%
time_list_ext_rtol6 = []
dt_array_ext_rtol6 = []
V_array_ext_rtol6 = []
f_array_ext_rtol6 = []
rhs_count_array_ext_rtol6 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../../../build/TANDEM_size101__AS_extendedode_5dp_Vrtol1e-06__EQ_extendedode_5dp_Vrtol1e-06.csv', newline='') as csvfile:
#with open('../results/TANDEM_size101__AS_extendedode_5dp_Vrtol1e-06__EQ_extendedode_5dp_Vrtol1e-06.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_rtol6.append(time)
            dt_array_ext_rtol6.append(dt)

            V_array_ext_rtol6.append(row['Vmax'])
            f_array_ext_rtol6.append(row['fmax'])
            rhs_count_array_ext_rtol6.append(row['count_rhs'])

time_array_ext_rtol6 = np.asarray(time_list_ext_rtol6, dtype=np.float64)
dt_array_ext_rtol6 = np.asarray(dt_array_ext_rtol6, dtype=np.float64)
V_array_ext_rtol6 = np.asarray(V_array_ext_rtol6, dtype=np.float64)
f_array_ext_rtol6 = np.asarray(f_array_ext_rtol6, dtype=np.float64)
rhs_count_array_ext_rtol6 = np.asarray(rhs_count_array_ext_rtol6, dtype=np.float64)

time_years_ext_rtol6 = time_array_ext_rtol6 / (365.2425*24*3600)

# %%
time_list_ext_rtol7 = []
dt_array_ext_rtol7 = []
V_array_ext_rtol7 = []
f_array_ext_rtol7 = []
rhs_count_array_ext_rtol7 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../../../build/TANDEM_size101__AS_extendedode_5dp_Vrtol1e-07__EQ_extendedode_5dp_Vrtol1e-07.csv', newline='') as csvfile:
#with open('../results/TANDEM_size101__AS_extendedode_5dp_Vrtol1e-07__EQ_extendedode_5dp_Vrtol1e-07.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_rtol7.append(time)
            dt_array_ext_rtol7.append(dt)

            V_array_ext_rtol7.append(row['Vmax'])
            f_array_ext_rtol7.append(row['fmax'])
            rhs_count_array_ext_rtol7.append(row['count_rhs'])

time_array_ext_rtol7 = np.asarray(time_list_ext_rtol7, dtype=np.float64)
dt_array_ext_rtol7 = np.asarray(dt_array_ext_rtol7, dtype=np.float64)
V_array_ext_rtol7 = np.asarray(V_array_ext_rtol7, dtype=np.float64)
f_array_ext_rtol7 = np.asarray(f_array_ext_rtol7, dtype=np.float64)
rhs_count_array_ext_rtol7 = np.asarray(rhs_count_array_ext_rtol7, dtype=np.float64)

time_years_ext_rtol7 = time_array_ext_rtol7 / (365.2425*24*3600)

# %%
time_list_ext_rtol8 = []
dt_array_ext_rtol8 = []
V_array_ext_rtol8 = []
f_array_ext_rtol8 = []
rhs_count_array_ext_rtol8 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../../../build/TANDEM_size101__AS_extendedode_5dp_Vrtol1e-08__EQ_extendedode_5dp_Vrtol1e-08.csv', newline='') as csvfile:
#with open('../results/TANDEM_size101__AS_extendedode_5dp_Vrtol1e-08__EQ_extendedode_5dp_Vrtol1e-08.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_rtol8.append(time)
            dt_array_ext_rtol8.append(dt)

            V_array_ext_rtol8.append(row['Vmax'])
            f_array_ext_rtol8.append(row['fmax'])
            rhs_count_array_ext_rtol8.append(row['count_rhs'])

time_array_ext_rtol8 = np.asarray(time_list_ext_rtol8, dtype=np.float64)
dt_array_ext_rtol8 = np.asarray(dt_array_ext_rtol8, dtype=np.float64)
V_array_ext_rtol8 = np.asarray(V_array_ext_rtol8, dtype=np.float64)
f_array_ext_rtol8 = np.asarray(f_array_ext_rtol8, dtype=np.float64)
rhs_count_array_ext_rtol8 = np.asarray(rhs_count_array_ext_rtol8, dtype=np.float64)

time_years_ext_rtol8 = time_array_ext_rtol8 / (365.2425*24*3600)

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

plt.plot(time_years_ext_rtol5, f_array_ext_rtol5,Color='forestgreen', label = r'$t_r=10^{-5}$')
plt.plot(time_years_ext_rtol6, f_array_ext_rtol6,Color='olive',       label = r'$t_r=10^{-6}$')
plt.plot(time_years_ext_rtol7, f_array_ext_rtol7,Color='goldenrod',   label = r'$t_r=10^{-7}$')
plt.plot(time_years_ext_rtol8, f_array_ext_rtol8,Color='firebrick',   label = r'$t_r=10^{-8}$')
#plt.plot(f_array_ext_rtol5,Color='forestgreen', label = r'$t_r=10^{-5}$')
#plt.plot(f_array_ext_rtol6,Color='olive',       label = r'$t_r=10^{-6}$')
#plt.plot(f_array_ext_rtol7,Color='goldenrod',   label = r'$t_r=10^{-7}$')
#plt.plot(f_array_ext_rtol8,Color='firebrick',   label = r'$t_r=10^{-8}$')

plt.xlabel("time [y]")
plt.ylabel("fmax")

plt.yscale('log')

plt.ylim(1e-8,1e-2)

plt.legend()

plt.savefig('../results/TANDEMtimeEvolutionFExtendedODEDifferentTolerances.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

n=50
f_array_ext_left  = np.copy(f_array_ext_rtol5)
f_array_ext_right = np.copy(f_array_ext_rtol5)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_rtol5_change = f_array_ext_left - f_array_ext_right
f_array_ext_rtol5_change = np.abs(f_array_ext_rtol5_change)
f_array_ext_rtol5_change /= 2*n

f_array_ext_left  = np.copy(f_array_ext_rtol6)
f_array_ext_right = np.copy(f_array_ext_rtol6)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_rtol6_change = f_array_ext_left - f_array_ext_right
f_array_ext_rtol6_change = np.abs(f_array_ext_rtol6_change)
f_array_ext_rtol6_change /= 2*n

f_array_ext_left  = np.copy(f_array_ext_rtol7)
f_array_ext_right = np.copy(f_array_ext_rtol7)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_rtol7_change = f_array_ext_left - f_array_ext_right
f_array_ext_rtol7_change = np.abs(f_array_ext_rtol7_change)
f_array_ext_rtol7_change /= 2*n

f_array_ext_left  = np.copy(f_array_ext_rtol8)
f_array_ext_right = np.copy(f_array_ext_rtol8)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_rtol8_change = f_array_ext_left - f_array_ext_right
f_array_ext_rtol8_change = np.abs(f_array_ext_rtol8_change)
f_array_ext_rtol8_change /= 2*n


plt.plot(time_years_ext_rtol5[n:-n], f_array_ext_rtol5_change[n:-n],Color='forestgreen', label = r'$t_r=10^{-5}$')
plt.plot(time_years_ext_rtol6[n:-n], f_array_ext_rtol6_change[n:-n],Color='olive',       label = r'$t_r=10^{-6}$')
plt.plot(time_years_ext_rtol7[n:-n], f_array_ext_rtol7_change[n:-n],Color='goldenrod',   label = r'$t_r=10^{-7}$')
plt.plot(time_years_ext_rtol8[n:-n], f_array_ext_rtol8_change[n:-n],Color='firebrick',   label = r'$t_r=10^{-8}$')
#plt.plot(f_array_ext_rtol5_change[n:-n],Color='forestgreen', label = r'$t_r=10^{-5}$')
#plt.plot(f_array_ext_rtol6_change[n:-n],Color='olive',       label = r'$t_r=10^{-6}$')
#plt.plot(f_array_ext_rtol7_change[n:-n],Color='goldenrod',   label = r'$t_r=10^{-7}$')
#plt.plot(f_array_ext_rtol8_change[n:-n],Color='firebrick',   label = r'$t_r=10^{-8}$')

plt.xlabel("time [y]")
plt.ylabel("change in fmax")

plt.yscale('log')

#plt.ylim(1e-8,1e-2)

plt.legend()

plt.savefig('../results/TANDEMtimeEvolutionFLTEExtendedODEDifferentTolerances.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
time_list_ext_size52 = []
dt_array_ext_size52 = []
V_array_ext_size52 = []
f_array_ext_size52 = []
rhs_count_array_ext_size52 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../../../build/TANDEM_size52__AS_extendedode_5dp_Vrtol1e-08__EQ_extendedode_5dp_Vrtol1e-08.csv', newline='') as csvfile:
#with open('../results/TANDEM_size52__AS_extendedode_5dp_Vrtol1e-08__EQ_extendedode_5dp_Vrtol1e-08.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_size52.append(time)
            dt_array_ext_size52.append(dt)

            V_array_ext_size52.append(row['Vmax'])
            f_array_ext_size52.append(row['fmax'])
            rhs_count_array_ext_size52.append(row['count_rhs'])

time_array_ext_size52 = np.asarray(time_list_ext_size52, dtype=np.float64)
dt_array_ext_size52 = np.asarray(dt_array_ext_size52, dtype=np.float64)
V_array_ext_size52 = np.asarray(V_array_ext_size52, dtype=np.float64)
f_array_ext_size52 = np.asarray(f_array_ext_size52, dtype=np.float64)
rhs_count_array_ext_size52 = np.asarray(rhs_count_array_ext_size52, dtype=np.float64)

time_years_ext_size52 = time_array_ext_size52 / (365.2425*24*3600)

# %%
time_list_ext_size200 = []
dt_array_ext_size200 = []
V_array_ext_size200 = []
f_array_ext_size200 = []
rhs_count_array_ext_size200 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../../../build/TANDEM_size200__AS_extendedode_5dp_Vrtol1e-08__EQ_extendedode_5dp_Vrtol1e-08.csv', newline='') as csvfile:
#with open('../results/TANDEM_size200__AS_extendedode_5dp_Vrtol1e-08__EQ_extendedode_5dp_Vrtol1e-08.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_size200.append(time)
            dt_array_ext_size200.append(dt)

            V_array_ext_size200.append(row['Vmax'])
            f_array_ext_size200.append(row['fmax'])
            rhs_count_array_ext_size200.append(row['count_rhs'])

time_array_ext_size200 = np.asarray(time_list_ext_size200, dtype=np.float64)
dt_array_ext_size200 = np.asarray(dt_array_ext_size200, dtype=np.float64)
V_array_ext_size200 = np.asarray(V_array_ext_size200, dtype=np.float64)
f_array_ext_size200 = np.asarray(f_array_ext_size200, dtype=np.float64)
rhs_count_array_ext_size200 = np.asarray(rhs_count_array_ext_size200, dtype=np.float64)

time_years_ext_size200 = time_array_ext_size200 / (365.2425*24*3600)

# %%
time_list_ext_size400 = []
dt_array_ext_size400 = []
V_array_ext_size400 = []
f_array_ext_size400 = []
rhs_count_array_ext_size400 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../../../build/TANDEM_size400__AS_extendedode_5dp_Vrtol1e-08__EQ_extendedode_5dp_Vrtol1e-08.csv', newline='') as csvfile:
#with open('../results/TANDEM_size400__AS_extendedode_5dp_Vrtol1e-08__EQ_extendedode_5dp_Vrtol1e-08.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            time_list_ext_size400.append(time)
            dt_array_ext_size400.append(dt)

            V_array_ext_size400.append(row['Vmax'])
            f_array_ext_size400.append(row['fmax'])
            rhs_count_array_ext_size400.append(row['count_rhs'])

time_array_ext_size400 = np.asarray(time_list_ext_size400, dtype=np.float64)
dt_array_ext_size400 = np.asarray(dt_array_ext_size400, dtype=np.float64)
V_array_ext_size400 = np.asarray(V_array_ext_size400, dtype=np.float64)
f_array_ext_size400 = np.asarray(f_array_ext_size400, dtype=np.float64)
rhs_count_array_ext_size400 = np.asarray(rhs_count_array_ext_size400, dtype=np.float64)

time_years_ext_size400 = time_array_ext_size400 / (365.2425*24*3600)

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

plt.plot(time_years_ext_size52,  f_array_ext_size52,  Color='gold',       label =r'$n=52$' )
plt.plot(time_years_ext_rtol8,   f_array_ext_rtol8,   Color='darkorange', label =r'$n=101$')
plt.plot(time_years_ext_size200, f_array_ext_size200, Color='red',        label =r'$n=200$')
plt.plot(time_years_ext_size400, f_array_ext_size400, Color='black',      label =r'$n=400$')

plt.xlabel("time [y]")
plt.ylabel("fmax")

plt.yscale('log')

plt.ylim(5e-9,2e-7)

plt.legend()

plt.savefig('../results/TANDEMtimeEvolutionFExtendedODEDifferentSizes.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

n=100
f_array_ext_left  = np.copy(f_array_ext_size52)
f_array_ext_right = np.copy(f_array_ext_size52)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_size52_change = f_array_ext_left - f_array_ext_right
f_array_ext_size52_change = np.abs(f_array_ext_size52_change)
f_array_ext_size52_change /= 2*n

f_array_ext_left  = np.copy(time_years_ext_rtol8)
f_array_ext_right = np.copy(time_years_ext_rtol8)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_size101_change = f_array_ext_left - f_array_ext_right
f_array_ext_size101_change = np.abs(f_array_ext_size101_change)
f_array_ext_size101_change /= 2*n

f_array_ext_left  = np.copy(f_array_ext_size200)
f_array_ext_right = np.copy(f_array_ext_size200)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_size200_change = f_array_ext_left - f_array_ext_right
f_array_ext_size200_change = np.abs(f_array_ext_size200_change)
f_array_ext_size200_change /= 2*n

f_array_ext_left  = np.copy(f_array_ext_size400)
f_array_ext_right = np.copy(f_array_ext_size400)
f_array_ext_left  = np.roll(f_array_ext_left,-n)
f_array_ext_right = np.roll(f_array_ext_right,+n)
f_array_ext_size400_change = f_array_ext_left - f_array_ext_right
f_array_ext_size400_change = np.abs(f_array_ext_size400_change)
f_array_ext_size400_change /= 2*n


plt.plot(time_years_ext_size52[n:-n],  f_array_ext_size52_change[n:-n],  Color='gold',       label =r'$n=52$' )
plt.plot(time_years_ext_rtol8[n:-n],   f_array_ext_size101_change[n:-n], Color='darkorange', label =r'$n=101$')
plt.plot(time_years_ext_size200[n:-n], f_array_ext_size200_change[n:-n], Color='red',        label =r'$n=200$')
plt.plot(time_years_ext_size400[n:-n], f_array_ext_size400_change[n:-n], Color='black',      label =r'$n=400$')

plt.xlabel("time [y]")
plt.ylabel("change of fmax")

plt.yscale('log')

#plt.ylim(1e-8,1e-2)

plt.legend()

plt.savefig('../results/TANDEMtimeEvolutionFLTEExtendedODEDifferentSizes.png', format='png',dpi=300, bbox_inches='tight')

plt.show()
