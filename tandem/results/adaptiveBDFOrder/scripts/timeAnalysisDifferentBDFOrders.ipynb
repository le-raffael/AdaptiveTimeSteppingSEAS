# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cbook as cbook
import csv
import pylab
from scipy.interpolate import interp1d


np.set_printoptions(threshold=sys.maxsize)

# %%
dt_array_BDF2 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_extendeddae_BDF2_sor-gmres_Satol1e-08__EQ_extendeddae_BDF2_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            dt_array_BDF2.append(dt)


dt_array_BDF2 = np.asarray(dt_array_BDF2, dtype=np.float64)

# %%
dt_array_BDF3 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_extendeddae_BDF3_sor-gmres_Satol1e-08__EQ_extendeddae_BDF3_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            dt_array_BDF3.append(dt)


dt_array_BDF3 = np.asarray(dt_array_BDF3, dtype=np.float64)

# %%
dt_array_BDF4 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_extendeddae_BDF4_sor-gmres_Satol1e-08__EQ_extendeddae_BDF4_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            dt_array_BDF4.append(dt)


dt_array_BDF4 = np.asarray(dt_array_BDF4, dtype=np.float64)

# %%
dt_array_BDF5 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_extendeddae_BDF5_sor-gmres_Satol1e-08__EQ_extendeddae_BDF5_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            dt_array_BDF5.append(dt)


dt_array_BDF5 = np.asarray(dt_array_BDF5, dtype=np.float64)

# %%
dt_array_BDF5_embedded = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_embedded_errorEvaluation_size101__AS_extendeddae_BDF5_sor-gmres_Satol1e-08__EQ_extendeddae_BDF5_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            dt_array_BDF5_embedded.append(dt)


dt_array_BDF5_embedded = np.asarray(dt_array_BDF5_embedded, dtype=np.float64)

# %%
dt_array_BDF6 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_extendeddae_BDF6_sor-gmres_Satol1e-08__EQ_extendeddae_BDF6_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            dt_array_BDF6.append(dt)


dt_array_BDF6 = np.asarray(dt_array_BDF6, dtype=np.float64)

# %%
dt_array_BDF0 = []
time_old = 0.0

#don't plot first two components
first = 1
second = 1

with open('../results/TANDEM_size101__AS_extendeddae_BDF0_sor-gmres_Satol1e-08__EQ_extendeddae_BDF0_sor-gmres_Satol1e-05.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if second:
            second = 0
        if first:
            first = 0
            second = 1
        else:
            time = row['time']
            dt = float(time) - time_old
            time_old = float(time)
            dt_array_BDF0.append(dt)


dt_array_BDF0 = np.asarray(dt_array_BDF0, dtype=np.float64)

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

#plt.plot(dt_array_BDF2,Color='firebrick',label='BDF2')
plt.plot(dt_array_BDF3[:1400],Color='darkorange',label='BDF3')
plt.plot(dt_array_BDF4[:700],Color='goldenrod',label='BDF4')
plt.plot(dt_array_BDF5[:500],Color='olive',label='BDF5')
plt.plot(dt_array_BDF6[:500],Color='forestgreen',label='BDF6')


plt.xlabel("step number")
plt.ylabel("timestep size [s]")
plt.legend(loc='lower right')

plt.yscale('log')
plt.ylim([1e-1,1e8])
#plt.xlim([0,2000])

plt.savefig('../results/TANDEMTimeAnalysisDifferentBDFOrdersLagrange_ExtendedDAE_Size101_Init.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(10.00,7.00))
plt.rcParams.update({'font.size': 18})

#plt.plot(dt_array_BDF2[1222:-1],Color='firebrick',label='BDF2')
plt.plot(dt_array_BDF3[9747:12902],Color='darkorange',label='BDF3')
plt.plot(dt_array_BDF4[4727:6228],Color='goldenrod',label='BDF4')
plt.plot(dt_array_BDF5[3166:4057],Color='olive',label='BDF5')
plt.plot(dt_array_BDF6[2554:3222],Color='forestgreen',label='BDF6')


plt.xlabel("step number after the aseismic slip")
plt.ylabel("timestep size [s]")
plt.legend(loc='upper right')

plt.yscale('log')

#plt.ylim([1e-1,1e8])
#plt.xlim([1,600])

plt.savefig('../results/TANDEMTimeAnalysisDifferentBDFOrdersLagrange_ExtendedDAE_Size101_Begin1stEQ.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(15.00,7.00))
plt.rcParams.update({'font.size': 18})

plt.plot(dt_array_BDF5,Color='black',label='Lagrangian polynomials')
plt.plot(dt_array_BDF5_embedded,Color='black',Linestyle='dashed',label='Embedded method')


plt.xlabel("step number")
plt.ylabel("timestep size [s]")
plt.legend()

plt.yscale('log')
#plt.ylim([1e-1,1e8])
#plt.xlim([0,2200])

plt.savefig('../results/TANDEMTimeAnalysisDifferentBDFOrdersEmbedded_vs_Lagrange_ExtendedDAE_Size101.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(15.00,7.00))
plt.rcParams.update({'font.size': 18})

#plt.plot(dt_array_BDF2,Color='firebrick',label='BDF2')
#plt.plot(dt_array_BDF3,Color='darkorange',label='BDF3')
plt.plot(dt_array_BDF4,Color='goldenrod',label='BDF4')
plt.axvline(x=np.size(dt_array_BDF4),Color='goldenrod',Linestyle='dashed')

plt.plot(dt_array_BDF5,Color='olive',label='BDF5')
plt.axvline(x=np.size(dt_array_BDF5),Color='olive',Linestyle='dashed')

plt.plot(dt_array_BDF6,Color='forestgreen',label='BDF6')
plt.axvline(x=np.size(dt_array_BDF6),Color='forestgreen',Linestyle='dashed')

plt.plot(dt_array_BDF0,Color='black',label='adaptive BDF')
plt.axvline(x=np.size(dt_array_BDF0),Color='black',Linestyle='dashed')



plt.xlabel("step number")
plt.ylabel("timestep size [s]")
plt.legend()

plt.yscale('log')
#plt.xlim([0,15000])

plt.savefig('../results/TANDEMTimeAnalysisDifferentBDFOrders_Lagrange_ExtendedDAE_Size101_FULLTIME.png', format='png',dpi=300, bbox_inches='tight')

plt.show()

# %%
print(np.where(dt_array_BDF3<1e-2))
# Out:
# (array([12902, 12903, 12904, 12905, 12906, 12907, 12908, 12909, 12910,
#        12911, 12912, 12913, 12916, 12917, 12918, 12919, 12920, 12921,
#        12922, 12923, 12924, 12925, 12926, 12927, 12928, 12929, 12930,
#        12931, 12933, 12934, 12935, 12936, 12937, 12938, 12939, 12940,
#        12941, 12942, 12956, 12957, 12958, 12959, 12960, 12961, 12962,
#        12963, 12964, 12965, 12966, 12967, 12968, 12969, 12970, 12971,
#        12972, 12973, 12974, 12975, 12976, 12977, 12978, 12979, 12980,
#        12981, 12982, 12983, 12984, 12985, 12986, 12987, 12988, 12989,
#        12990, 12991, 12992, 12993, 12994, 12995, 12996, 12997, 12998,
#        12999, 13000, 13001, 13002, 13003, 13004, 13005, 13006, 13007,
#        13008, 13009, 13010, 13011, 13012, 13013, 13014, 13015, 13016,
#        13017, 13018, 13019, 13020, 13021, 13022, 13023, 13024, 13025,
#        13026, 13027, 13028, 13029, 13030, 13031, 13032, 13033, 13034,
# ...
